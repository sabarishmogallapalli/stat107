# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - Refer to your **lecture notebook** and the **pandas cheat sheet** to help you out with the code!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Daniel"
ca1_name = "Linh"
ca2_name = "Eeshan"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "David Mocianko"
partner1_netid = "dmoci2"
partner1_inYourGroupLastWeek = "yes"

partner2_name = "Shane Moncayl"
partner2_netid = "moncayo3"
partner1_inYourGroupLastWeek = "yes"

partner3_name = "Evan Walker"
partner3_netid = "evanaw3"
partner1_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the "Hello Dataset".  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *(Are you taking RHET 105 this semester?)*

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa22.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`:

# %%
df=pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa22.csv")
df
# Out:
#              Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0          CA Ana  AL1                    2.0                    5.0
# 1          CA Ram  AYR                    2.0                    5.0
# 2          CA Xin  AYO                    1.0                    5.0
# 3           Lekha  AYH                    2.0                    2.0
# 4            Reni  AYD                    2.0                    5.0
# ..            ...  ...                    ...                    ...
# 519          Bill  AYC                    1.0                    5.0
# 520       Renault  AYR                    2.0                    5.0
# 521  Shivam Patel  AYC                    1.0                    3.0
# 522         Colin  AYI                    1.0                    5.0
# 523          Evan  AYG                    2.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# 1                                            2-Jan                 7UP
# 2                                            2-Jan         Sierra Mist
# 3                                              0.5                 7UP
# 4                                            2-Jan                 7UP
# ..                                             ...                 ...
# 519                                          2-Jan         Sierra Mist
# 520                                            0.5         Sierra Mist
# 521                                            0.5                 7UP
# 522                                          2-Jan         Sierra Mist
# 523                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 0               iOS            Apple          Pork   On/Before June 30  ...
# 1               iOS            Apple           NaN     On/After July 1  ...
# 2               iOS            Apple          Beef   On/Before June 30  ...
# 3               iOS           Orange          Pork     On/After July 1  ...
# 4               iOS            Apple          Pork   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 519             iOS            Apple          Beef     On/After July 1  ...
# 520         Android           Orange          Pork   On/Before June 30  ...
# 521             iOS            Apple           NaN   On/Before June 30  ...
# 522             iOS           Orange          Beef   On/Before June 30  ...
# 523         Android           Orange          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 0                                  Cold brew
# 1                               Black coffee
# 2                                  starbucks
# 3                        pumpkin spice latte
# 4                                      Mocha
# ..                                       ...
# 519                                      NaN
# 520                                     moca
# 521                          Don’t have one
# 522                                      tea
# 523                                      Tea
#
#     What is your favorite mobile app?  What is your favorite subject?  \
# 0                            Snapchat                            Math
# 1                      Google chrome                      Mathematics
# 2                           Starbucks                      Psychology
# 3                             twitter               english (writing)
# 4                           Instagram                            Math
# ..                                ...                             ...
# 519                               NaN                             NaN
# 520                           wechat                              cs
# 521                           Youtube                  World History
# 522                           YouTube                            Math
# 523                          Facebook  Probability and Measure Theory
#
#     Who is your favorite singer? What is your favorite season?  \
# 0                   Taylor Swift                          Fall
# 1                          TWICE                        Spring
# 2                  Five Exercuse                        Winter
# 3                   lana del rey                        autumn
# 4                  Mark kozelek                         Winter
# ..                           ...                           ...
# 519                          NaN                           NaN
# 520              Michael Jackson                        Spring
# 521                   Kumar Sanu                        Summer
# 522                   The Weeknd                        Summer
# 523               Fredie Mercury                        Winter
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 0                      Piceis                         Minecraft
# 1                     Scorpio      Player Unkown's Battleground
# 2                    aquarius                              None
# 3                         leo                   animal crossing
# 4                    Aquarias                 Rainbow six siege
# ..                        ...                               ...
# 519                       NaN                               NaN
# 520                       idk                       WOW classic
# 521                 Aquarius                            FIFA 20
# 522                 Aquarious                     Rocket League
# 523                     Libra                         Uncharted
#
#     What is your favorite non-video game? What is your favorite food?  \
# 0                      Chutes and Ladders                      Yogurt
# 1                              Basketball                        Rice
# 2                                    None                       Eggs
# 3                                   catan                  tteokbokki
# 4                                   Catan                       Tacos
# ..                                    ...                         ...
# 519                                   NaN                         NaN
# 520                             badminton                        rice
# 521                                 Chess                       Pizza
# 522                                 Poker                       Tacos
# 523                            Basketball             Eggs with bacon
#
#     What's your favorite movie?
# 0                             ?
# 1               The conjouring
# 2                       Flipped
# 3                   dune (2021)
# 4            End of Evangelion
# ..                          ...
# 519                         NaN
# 520        guardians of gahoole
# 521            Avengers Endgame
# 522                   Inception
# 523                Interstellar
#
# [524 rows x 120 columns]

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **in a text editor** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Lab',
#  'Number 1 or Number 2?',
#  'Number 3 or Number 5?',
#  'What is your preferred way of saying one half?',
#  '7UP or Sierra Mist?',
#  'Android or iOS?',
#  'Apple or Orange?',
#  'Beef or Pork?',
#  'Your birthday is...',
#  'Do you prefer to wear black or white?',
#  'Boba or Coffee?',
#  'Cake or Pie?',
#  'Canes or Chick-fil-a?',
#  'Do you pour milk or cereal first?',
#  'Do you prefer chocolate or vanilla?',
#  'Coffee or Tea?',
#  'Coke or Pepsi?',
#  'Cookies or Ice Cream?',
#  'Do you prefer ice cream in a cup or in a cone?',
#  'Do you prefer dad or mom?',
#  'Marvel or DC?',
#  'Are you living in a dorm or an apartment?',
#  'Your last digit in your NetID...',
#  'Were you born in an even or odd month of the year?',
#  'Would you rather have the superpower of flight or invisibility?',
#  'UIUC Football or Basketball Team?',
#  'French Fries or Tater Tots?',
#  'Heads or Tails?',
#  'Hot Weather or Cold Weather?',
#  'Hot Dogs or Hamburgers?',
#  'In-State or Out-of-State/International',
#  'Introvert or Extrovert?',
#  'Do you consider yourself to have long or short hair?',
#  'Do you primarily use Windows or Mac?',
#  'You Identify As?',
#  'Morning Person or Night Person?',
#  'Favorite Root Beer Brand',
#  'Do you prefer the letter N or the letter M?',
#  'Does pineapple belong on pizza?',
#  'Is the day of the month your birthday falls on even or odd?',
#  'Is the year of your birthday even or odd?',
#  'Do you like partying at the University of Urbana-Champaign or do you want to go back home?',
#  'Do you prefer pens or pencils?',
#  'Pink or Blue',
#  'Pizza or Burger',
#  'Pizza or Sushi',
#  'What subject do you prefer?',
#  'Do you prefer rain or clear weather?',
#  'Pizza or Ramen',
#  'Rap Music or Pop Music?',
#  'Red or Blue?',
#  'Regular Cakes or Cupcakes?',
#  'Spring or Fall?',
#  'Starbucks or Dunkin?',
#  'Is your major STEM or non STEM?',
#  'Strawberry or Melon?',
#  'Summer or Winter?',
#  'Who would win: Superman or Homelander?',
#  'Which came first, the chicken or the egg?',
#  'The Office or Friends?',
#  'TV Shows or Movies?',
#  'Are you an upperclassmen or an underclassmen?',
#  'Pancakes or Waffles?',
#  'XBox or Playstation?',
#  'Do you have any pets?',
#  'Will you turn 19 before October?',
#  'Do you eat breakfast?',
#  'Do you like deep dish pizza?',
#  'Is this your first year at UIUC?',
#  'Do you drive a car?',
#  'Are you a dog person?',
#  'Is a hotdog a sandwich?',
#  'Do you use the busses?',
#  'Do you wear glasses?',
#  'Do you have a TV in your room?',
#  'Did you go to the Illinois vs Wyoming game last Saturday?',
#  'Are you taking RHET 105 this semester?',
#  'When did you wake up today?',
#  'Do you have a sibling?',
#  'Have you ever gotten COVID-19?',
#  'Do you bring a water bottle to class?',
#  'How many credit hours are you taking this semester?',
#  'Do you like school dorms?',
#  'How tall are you?',
#  'Do you play any sports?',
#  'Are your ears pierced?',
#  'Do you believe in life on other planets?',
#  'Do you have experience with computer programming before DISCOVERY?',
#  'Does your UIN end with an even number?',
#  'Study Strategy: Stay Up Late or Get Up Early?',
#  'Have you ever had a student loan?',
#  'Data Science DISCOVERY is',
#  'Do you fold up or ball toilet paper?',
#  'What day during the month is your birthday?',
#  'At what age do you think you will die?',
#  'From 1 to 10, how happy are you right now?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking this semester?.1',
#  'How many classes do you have on Friday?',
#  'How many countries have you been to outside the US?',
#  'How many hours of sleep did you get last night?',
#  'How many hours of sleep do you get on average?',
#  'How many meals do you have one day?',
#  'How many pets do you have?',
#  'How many roommates do you have?',
#  'How many siblings do you have?',
#  'How many years do you plan to study at university?',
#  'What is your favorite number?',
#  'What was your second choice for college (excluding your top choice of UIUC)?',
#  'What is your favorite coffee shop drink?',
#  'What is your favorite mobile app?',
#  'What is your favorite subject?',
#  'Who is your favorite singer?',
#  'What is your favorite season?',
#  'What is your Zodiac sign?',
#  'What is your favorite video game?',
#  'What is your favorite non-video game?',
#  'What is your favorite food?',
#  "What's your favorite movie?"]

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your question's column name in the variable `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column = "Are you taking RHET 105 this semester?"
analysis_column
# Out:
# 'Are you taking RHET 105 this semester?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( analysis_column in df ), "Make certain your analysis_column is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you may want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the set for `df`, and the second set for the column name.
# - You can find this syntax under the "Subset Variables (Columns)" on your cheat sheet!
#
# Us Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[["Are you taking RHET 105 this semester?"]]
# Out:
#     Are you taking RHET 105 this semester?
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
# ..                                     ...
# 519                                     No
# 520                                     No
# 521                                     No
# 522                                     No
# 523                                     No
#
# [524 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[(df["Are you taking RHET 105 this semester?"]=="No")]
df1
# Out:
#              Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0          CA Ana  AL1                    2.0                    5.0
# 1          CA Ram  AYR                    2.0                    5.0
# 2          CA Xin  AYO                    1.0                    5.0
# 3           Lekha  AYH                    2.0                    2.0
# 4            Reni  AYD                    2.0                    5.0
# ..            ...  ...                    ...                    ...
# 519          Bill  AYC                    1.0                    5.0
# 520       Renault  AYR                    2.0                    5.0
# 521  Shivam Patel  AYC                    1.0                    3.0
# 522         Colin  AYI                    1.0                    5.0
# 523          Evan  AYG                    2.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# 1                                            2-Jan                 7UP
# 2                                            2-Jan         Sierra Mist
# 3                                              0.5                 7UP
# 4                                            2-Jan                 7UP
# ..                                             ...                 ...
# 519                                          2-Jan         Sierra Mist
# 520                                            0.5         Sierra Mist
# 521                                            0.5                 7UP
# 522                                          2-Jan         Sierra Mist
# 523                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 0               iOS            Apple          Pork   On/Before June 30  ...
# 1               iOS            Apple           NaN     On/After July 1  ...
# 2               iOS            Apple          Beef   On/Before June 30  ...
# 3               iOS           Orange          Pork     On/After July 1  ...
# 4               iOS            Apple          Pork   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 519             iOS            Apple          Beef     On/After July 1  ...
# 520         Android           Orange          Pork   On/Before June 30  ...
# 521             iOS            Apple           NaN   On/Before June 30  ...
# 522             iOS           Orange          Beef   On/Before June 30  ...
# 523         Android           Orange          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 0                                  Cold brew
# 1                               Black coffee
# 2                                  starbucks
# 3                        pumpkin spice latte
# 4                                      Mocha
# ..                                       ...
# 519                                      NaN
# 520                                     moca
# 521                          Don’t have one
# 522                                      tea
# 523                                      Tea
#
#     What is your favorite mobile app?  What is your favorite subject?  \
# 0                            Snapchat                            Math
# 1                      Google chrome                      Mathematics
# 2                           Starbucks                      Psychology
# 3                             twitter               english (writing)
# 4                           Instagram                            Math
# ..                                ...                             ...
# 519                               NaN                             NaN
# 520                           wechat                              cs
# 521                           Youtube                  World History
# 522                           YouTube                            Math
# 523                          Facebook  Probability and Measure Theory
#
#     Who is your favorite singer? What is your favorite season?  \
# 0                   Taylor Swift                          Fall
# 1                          TWICE                        Spring
# 2                  Five Exercuse                        Winter
# 3                   lana del rey                        autumn
# 4                  Mark kozelek                         Winter
# ..                           ...                           ...
# 519                          NaN                           NaN
# 520              Michael Jackson                        Spring
# 521                   Kumar Sanu                        Summer
# 522                   The Weeknd                        Summer
# 523               Fredie Mercury                        Winter
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 0                      Piceis                         Minecraft
# 1                     Scorpio      Player Unkown's Battleground
# 2                    aquarius                              None
# 3                         leo                   animal crossing
# 4                    Aquarias                 Rainbow six siege
# ..                        ...                               ...
# 519                       NaN                               NaN
# 520                       idk                       WOW classic
# 521                 Aquarius                            FIFA 20
# 522                 Aquarious                     Rocket League
# 523                     Libra                         Uncharted
#
#     What is your favorite non-video game? What is your favorite food?  \
# 0                      Chutes and Ladders                      Yogurt
# 1                              Basketball                        Rice
# 2                                    None                       Eggs
# 3                                   catan                  tteokbokki
# 4                                   Catan                       Tacos
# ..                                    ...                         ...
# 519                                   NaN                         NaN
# 520                             badminton                        rice
# 521                                 Chess                       Pizza
# 522                                 Poker                       Tacos
# 523                            Basketball             Eggs with bacon
#
#     What's your favorite movie?
# 0                             ?
# 1               The conjouring
# 2                       Flipped
# 3                   dune (2021)
# 4            End of Evangelion
# ..                          ...
# 519                         NaN
# 520        guardians of gahoole
# 521            Avengers Endgame
# 522                   Inception
# 523                Interstellar
#
# [476 rows x 120 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[(df["Are you taking RHET 105 this semester?"]=="Yes")]
df2
# Out:
#               Name   Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 32          Beomsu   AYD                    1.0                    5.0
# 50           Yihao   AYS                    2.0                    5.0
# 58        Matthew    AYP                    2.0                    3.0
# 77            Reva   AL1                    2.0                    3.0
# 79         Bernard   AYN                    1.0                    5.0
# 99            Sean   AYS                    1.0                    3.0
# 100          Kyle    AYJ                    1.0                    3.0
# 114        Yuxiang   AYE                    1.0                    5.0
# 115         Jeremy   AYO                    1.0                    3.0
# 119       Sabarish   AYD                    2.0                    5.0
# 138           Sean   AYJ                    2.0                    3.0
# 140         Andrew   AYF                    1.0                    3.0
# 154          Henri   LBD                    1.0                    5.0
# 158           Sota   AYT                    1.0                    5.0
# 173       Jonathan   AYR                    2.0                    3.0
# 198            Tom   AYD                    2.0                    5.0
# 208          Jimmy   AYA                    1.0                    3.0
# 221       Scarlett   AYJ                    2.0                    5.0
# 222          Grace   AYD                    1.0                    3.0
# 225      zhenqiang   AYA                    1.0                    3.0
# 233           Rama   AYL                    1.0                    5.0
# 243           Evan   AYD                    1.0                    5.0
# 248         Ishaan   AYR                    1.0                    3.0
# 275      Seongwook   AYE                    2.0                    3.0
# 283          Harry   AYE                    1.0                    3.0
# 285  Daksheshkaran   AYP                    1.0                    5.0
# 286          JACKY   AYA                    1.0                    3.0
# 303       Pranavi    AYJ                    2.0                    5.0
# 310      Changrong   AYL                    1.0                    5.0
# 325        Stephen   AYN                    1.0                    3.0
# 332          Lanbu  BYOD                    1.0                    3.0
# 337            Ben   AYA                    1.0                    3.0
# 344       Anushree   AYH                    2.0                    5.0
# 346        Michael   AYI                    1.0                    3.0
# 357         Rishab   AYG                    2.0                    3.0
# 388          Tanya   AYC                    2.0                    3.0
# 399           Feng  Stat                    1.0                    3.0
# 421         Gianni   AYP                    1.0                    5.0
# 436           Lizy   LBD                    2.0                    5.0
# 450         Andrew   AYA                    1.0                    3.0
# 452         Luyang   AYB                    1.0                    5.0
# 467      Jeonghwan   AYL                    1.0                    3.0
# 468           jake   LBD                    2.0                    5.0
# 493          Yuang   AYF                    1.0                    3.0
# 495          Aiden   AL1                    2.0                    3.0
# 500            Ray   AYO                    2.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 32                                           2-Jan         Sierra Mist
# 50                                           2-Jan         Sierra Mist
# 58                                             0.5                 7UP
# 77                                           2-Jan         Sierra Mist
# 79                                           2-Jan                 7UP
# 99                                           2-Jan                 7UP
# 100                                            0.5         Sierra Mist
# 114                                          2-Jan                 7UP
# 115                                          2-Jan                 7UP
# 119                                          2-Jan                 7UP
# 138                                          2-Jan         Sierra Mist
# 140                                            0.5         Sierra Mist
# 154                                          2-Jan         Sierra Mist
# 158                                          2-Jan                 7UP
# 173                                            0.5                 7UP
# 198                                            0.5                 7UP
# 208                                          2-Jan                 7UP
# 221                                            NaN                 NaN
# 222                                          2-Jan                 7UP
# 225                                          2-Jan         Sierra Mist
# 233                                          2-Jan                 7UP
# 243                                          2-Jan         Sierra Mist
# 248                                          2-Jan                 7UP
# 275                                          2-Jan                 7UP
# 283                                            0.5                 7UP
# 285                                            0.5                 7UP
# 286                                          2-Jan                 7UP
# 303                                          2-Jan                 7UP
# 310                                          2-Jan         Sierra Mist
# 325                                          2-Jan         Sierra Mist
# 332                                          2-Jan                 7UP
# 337                                          2-Jan         Sierra Mist
# 344                                            0.5         Sierra Mist
# 346                                            0.5                 7UP
# 357                                          2-Jan                 7UP
# 388                                          2-Jan                 7UP
# 399                                          2-Jan                 7UP
# 421                                          2-Jan         Sierra Mist
# 436                                          2-Jan                 7UP
# 450                                          2-Jan                 7UP
# 452                                            0.5         Sierra Mist
# 467                                          2-Jan                 7UP
# 468                                          2-Jan                 7UP
# 493                                          2-Jan         Sierra Mist
# 495                                          2-Jan                 7UP
# 500                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 32              iOS            Apple          Pork   On/Before June 30  ...
# 50              iOS           Orange          Beef     On/After July 1  ...
# 58              iOS           Orange          Beef   On/Before June 30  ...
# 77          Android            Apple           NaN     On/After July 1  ...
# 79              iOS           Orange          Beef   On/Before June 30  ...
# 99              iOS            Apple          Beef     On/After July 1  ...
# 100             iOS            Apple          Beef   On/Before June 30  ...
# 114         Android           Orange          Beef   On/Before June 30  ...
# 115             iOS            Apple          Beef   On/Before June 30  ...
# 119             iOS            Apple          Pork   On/Before June 30  ...
# 138             iOS            Apple          Beef     On/After July 1  ...
# 140         Android            Apple          Pork   On/Before June 30  ...
# 154             iOS            Apple          Beef   On/Before June 30  ...
# 158             iOS            Apple          Beef   On/Before June 30  ...
# 173         Android            Apple          Beef     On/After July 1  ...
# 198             iOS           Orange          Beef   On/Before June 30  ...
# 208             iOS            Apple          Beef   On/Before June 30  ...
# 221             iOS           Orange          Beef     On/After July 1  ...
# 222             iOS            Apple          Beef     On/After July 1  ...
# 225             iOS            Apple          Beef     On/After July 1  ...
# 233             iOS           Orange          Pork   On/Before June 30  ...
# 243             iOS            Apple          Pork   On/Before June 30  ...
# 248             iOS            Apple          Beef   On/Before June 30  ...
# 275         Android           Orange          Beef   On/Before June 30  ...
# 283             iOS            Apple          Beef     On/After July 1  ...
# 285             iOS            Apple          Pork   On/Before June 30  ...
# 286             iOS            Apple          Beef     On/After July 1  ...
# 303             iOS            Apple          Pork     On/After July 1  ...
# 310             iOS            Apple          Beef     On/After July 1  ...
# 325             iOS           Orange          Beef   On/Before June 30  ...
# 332             iOS            Apple          Beef   On/Before June 30  ...
# 337             iOS           Orange          Pork   On/Before June 30  ...
# 344             iOS           Orange          Pork   On/Before June 30  ...
# 346             iOS            Apple          Beef   On/Before June 30  ...
# 357             iOS           Orange          Beef     On/After July 1  ...
# 388             iOS           Orange          Pork   On/Before June 30  ...
# 399             iOS            Apple          Beef   On/Before June 30  ...
# 421             iOS            Apple          Beef   On/Before June 30  ...
# 436             iOS            Apple          Beef   On/Before June 30  ...
# 450             iOS            Apple          Beef     On/After July 1  ...
# 452             iOS            Apple          Beef   On/Before June 30  ...
# 467             iOS           Orange          Beef     On/After July 1  ...
# 468             iOS            Apple          Beef     On/After July 1  ...
# 493             iOS            Apple          Beef     On/After July 1  ...
# 495         Android            Apple          Beef   On/Before June 30  ...
# 500         Android            Apple          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 32                                 americano
# 50                             Ice Americano
# 58                         Caramel Macchiato
# 77          White chocolate creme frappucino
# 79                                 Starbucks
# 99                                 Starbucks
# 100                            matcha latte
# 114                                      NaN
# 115                              Apple juice
# 119         Java Chip Frappacino - Starbucks
# 138                                   coffee
# 140                                   Coffee
# 154          Iced coffee with milk and sugar
# 158                                      NaN
# 173                                Green Tea
# 198                                     Milk
# 208                                    Latte
# 221                            hot chocolate
# 222                                  dunkin
# 225                                Starbucks
# 233                            Hot chocolate
# 243                                 Lemonade
# 248                        Caramel Machiatto
# 275                           don't have one
# 283                                starbucks
# 285                            Hot Chocolate
# 286                                americano
# 303                           vanilla latte
# 310                                Starbucks
# 325                               Cappuccino
# 332                                 hot coco
# 337                             black coffee
# 344                               cold brew
# 346                                    Water
# 357                             Black Coffee
# 388                      iced vanilla latte
# 399                                       No
# 421          Iced Caramel Latte with OatMilk
# 436                               Iced Latte
# 450                                Starbucks
# 452                                 Starbuck
# 467                                Starbucks
# 468                             black coffee
# 493                                Starbucks
# 495                                java chip
# 500                                    water
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 32                          Instagram              Computer Science
# 50                    Little red book                          Music
# 58                       Google Maps                     Statistics
# 77                          instagram                           STAT
# 79                           Snapchat                            P.E
# 99                            YouTube                    Mathematics
# 100                        instagram                             NaN
# 114                               NaN                             CS
# 115                           Youtube               Computer Science
# 119                         Instagram                           Math
# 138                           youtube                             cs
# 140                           Youtube                    Mathematics
# 154                    Clash of Clans                           Stat
# 158                         Instagram                           Math
# 173                         Instagram                             CS
# 198                                QQ                     Psychology
# 208                              Uber                          STATS
# 221                               NaN                            NaN
# 222                           youtube                           Math
# 225                            Wechat                           Math
# 233                         Instagram                           Math
# 243                          Messages             Data Discovery 107
# 248                            Tiktok               Computer Science
# 275                            dokkan                 Statistics 107
# 283                           youtube                        science
# 285                           Twitter                    Mathematics
# 286                             steam                             CS
# 303                          Netflix                     statistics
# 310                            wechat                     basketball
# 325                            twitch                           Math
# 332                            Naruto                             PE
# 337                         instagram                     statistics
# 344                            BeReal                           Math
# 346                         Instagram                           Math
# 357                            TikTok               Computer Science
# 388                          snapchat                     philosophy
# 399                            Tiktok                           Math
# 421                            Tiktok                       Business
# 436                          Tik Tok                          STATS
# 450                           youtube               Computer Science
# 452                            TikTok                        history
# 467                           YouTube                             IS
# 468                           tic tok                           math
# 493                            Wechat                      Statistic
# 495                          snapchat                        stat107
# 500                            Aidoku                       business
#
#     Who is your favorite singer? What is your favorite season?  \
# 32                   Central cee                       Winter
# 50                     Lady Gaga                        Autumn
# 58                Frank Sinatra                         Winter
# 77                  Taylor Swift                        Spring
# 79                          Joji                        Summer
# 99                       VIichan                        Winter
# 100                        Keshi                          fall
# 114                          NaN                           NaN
# 115                          NaN                          Fall
# 119                   Bruno Mars                          Fall
# 138                   jonas blue                        autumn
# 140                  kurt cobain                          Fall
# 154                   Bob Marley                        Winter
# 158                          NaN                        Summer
# 173                     Jay Chou                          Fall
# 198                Mike Oldfield                        Spring
# 208                  Alan Walker                          Fall
# 221                          NaN                          fall
# 222                     Duo Lipa                        Summer
# 225                       Beyond                          Fall
# 233                Ariana Grande                        Summer
# 243                        Tails                          Fall
# 248              Michael Jackson                        Spring
# 275               don't have one                        winter
# 283                billie eilish                        spring
# 285                 Taylor Swift                        Winter
# 286                           JB                        spring
# 303                   The Weeknd                       summer
# 310                       Eminem                        Summer
# 325                     Maroon 5                        Winter
# 332                       Capper                        Spring
# 337                         yeat                          fall
# 344                    Baby Keem                          Fall
# 346                   Kanye West                        Summer
# 357                 Taylor Swift                          Fall
# 388                 Lil uzi vert                        spring
# 399                     Jay Chou                          Fall
# 421               Kendrick Lamar                        Summer
# 436              Phoebe Bridgers                       Spring
# 450                   John Mayer                        winter
# 452                     jay chou                        summer
# 467                       Eminem                        Winter
# 468                 Johnny cash                         spring
# 493                       Beyond                          Fall
# 495                        Oasis                        winter
# 500        Ikuta Lilas (YOASOBI)                        Winter
#
#         What is your Zodiac sign? What is your favorite video game?  \
# 32                         Sheep                          Valorant
# 50                          Virgo                             GTA 5
# 58                         Gemini        Call of Duty: Black Ops II
# 77                          Aries                          Mabinogi
# 79                         Pieces                Ghost of Tsushima
# 99                    Sagittarius                          Valorant
# 100                        gemini                        Pokemon go
# 114                           NaN                               NaN
# 115                        Taurus         Super Smash Bros Ultimate
# 119                         Virgo                             Forza
# 138                        cancer                              apex
# 140                        Gemini                          Factorio
# 154                     Capricorn                  Feeding Frenzy 2
# 158                      Aquarius                        Smash Bros
# 173                           Leo                            Sudoku
# 198                        Taurus                         HighFleet
# 208                           PSC                         Fall Guys
# 221                           NaN                               NaN
# 222                         Virgo                             Zelda
# 225                         sheep                              none
# 233                        Pisces                              FIFA
# 243                        Gemini         Super Smash Bros Ultimate
# 248                        Pisces                          Fortnite
# 275                        Tauras           Pokemon Black and White
# 283                        cancer                           fallout
# 285                        Pisces                           FIFA 22
# 286                         sheep                              csgo
# 303                       cancer                        Mario cart
# 310                       Scorpio                              Apex
# 325                        taurus                             GTA V
# 332                         Aries                            Naruto
# 337                        gemini                                2k
# 344                        Pisces                        Overcooked
# 346                        Gemini                    Clash of Clans
# 357                         Libra                         Minecraft
# 388                        pisces             call of duty zombies
# 399                            no                     Honor of King
# 421                        Gemini                             NBA2K
# 436                        Aries                        Smash Bros
# 450                           leo                          valorant
# 452  I do not know what is zodiac                              apex
# 467                        Cancer                            Tekken
# 468                           leo                         pga tour
# 493                         libra                              CSGO
# 495                        taurus                            league
# 500                        Cancer                     Rocket League
#
#     What is your favorite non-video game? What is your favorite food?  \
# 32                                  poker                       Pizza
# 50                                    NaN             Pineapple apple
# 58                              My family                     Salmon
# 77                       Apples to Apples                     Noodles
# 79                            spike ball?                mexican food
# 99                               Monopoly                       Sushi
# 100                           basketball                          NaN
# 114                                   NaN                         NaN
# 115                            Kingdomino                Cookie Dough
# 119                              Monopoly               Chicken Wings
# 138                                 poker               fried noodles
# 140                                 Chess                   Ice cream
# 154                                 Poker             Shrimp Cocktail
# 158                                   NaN                Cheeseburger
# 173                              Monopoly                       Sushi
# 198                              Monopoly                     Sashimi
# 208                                   UNO             Shrimp Dumpling
# 221                            boardgames                         NaN
# 222                                   uno                    briscuit
# 225                                Kungfu                        Rice
# 233                         Secret Hitler                       Pizza
# 243                            Basketball          Chinese pork belly
# 248                            Basketball                      Cereal
# 275                                 Poker                       curry
# 283                         hide and seek                       chili
# 285                                   Uno              Chicken Burger
# 286                                  unio                       Buger
# 303                             monopoly                       sushi
# 310                         I am the boss                    hot dogs
# 325                              cashflow                      Fillet
# 332                            basketball                       apple
# 337                            basketball             al pastor tacos
# 344                               Contact              mac and cheese
# 346                              Monopoly                   Hamburger
# 357                          Clash Royale                   Taco Bell
# 388                      sorry boardgame                 shrimp tacos
# 399                                soccer                       Rice
# 421                             Parchessi                Mexican Food
# 436                              Mancala              Sub Sandwiches
# 450                            basketball                      cheeze
# 452                                   GTA                    dumpling
# 467                     League of Legends                        Meat
# 468                        texas hold em                        steak
# 493                                   NaN                       Sushi
# 495                              monopoly                  mac&cheese
# 500                                  golf                    Takoyaki
#
#          What's your favorite movie?
# 32                    Fast & Furious
# 50                        Fight Club
# 58                             Mulan
# 77                    Don't have one
# 79                           Top Gun
# 99                    Ford v Ferrari
# 100                         hobbits
# 114                              NaN
# 115                     Infinity War
# 119              Wolf of Wall Street
# 138                   now you see me
# 140                  American Psycho
# 154                        Gladiator
# 158                       Glory Road
# 173         The theory of everything
# 198         The Grand Budapest Hotel
# 208         The Shawshank Redemption
# 221                              NaN
# 222            avengers infinity war
# 225                         Iron man
# 233                Avengers: Endgame
# 243  The Good, the Bad, and the Ugly
# 248                         3 idiots
# 275                   The lego movie
# 283               batman dark knight
# 285                       Battleship
# 286                   the green book
# 303               crazy rich asians
# 310                       green book
# 325                    The Shawshank
# 332                Naruto：Ninja road
# 337                         superbad
# 344                     Interstellar
# 346   Star Wars - Return of the Jedi
# 357                               Us
# 388              catch me if you can
# 399                             Love
# 421                      Grown Ups 1
# 436                    Spider Man 3
# 450              Night at the Museum
# 452                       iron man 2
# 467                            Tenet
# 468                    happy gilmore
# 493                       Xiyangyang
# 495                  Revenge of Sith
# 500                    Kimi no na wa
#
# [46 rows x 120 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# *(476/522 people answered no. This translates to 91.2%. The remaining 46/522 people answered yes. This translates to 8.8%. The total amount of people who responded were 522. 524 people were asked. Two people didn't answer.)*

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# *(I was surprised by the answers that were provided. I felt that the results would be closer to a 50/50 split but the majority of people, almost all of them, weren't taking it this semester with only a few people taking it this semester. This was very surprising.)*

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# *(No)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# Select half (50%) of the participants to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#         Name       Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 313   Jaypal       AYT                    1.0                    5.0
# 187   Dhiraj       AYQ                    2.0                    5.0
# 430   Karena       AL1                    2.0                    3.0
# 509     Tess       AYC                    2.0                    5.0
# 472  CA Linh  AYD, AYF                    1.0                    3.0
# ..       ...       ...                    ...                    ...
# 364   Junhao       AYN                    1.0                    3.0
# 400  Jeffrey       AYS                    2.0                    5.0
# 131  Sarthak       AYB                    2.0                    5.0
# 81      Anne       AYP                    1.0                    5.0
# 155    Grace       AYN                    1.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 313                                            0.5                 7UP
# 187                                          2-Jan                 7UP
# 430                                          2-Jan         Sierra Mist
# 509                                          2-Jan                 7UP
# 472                                          2-Jan                 7UP
# ..                                             ...                 ...
# 364                                          2-Jan                 7UP
# 400                                            0.5                 7UP
# 131                                          2-Jan         Sierra Mist
# 81                                             0.5         Sierra Mist
# 155                                            0.5                 NaN
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 313             iOS            Apple          Pork   On/Before June 30  ...
# 187             iOS            Apple          Beef   On/Before June 30  ...
# 430             iOS            Apple          Beef   On/Before June 30  ...
# 509             iOS            Apple          Beef   On/Before June 30  ...
# 472             iOS           Orange          Pork   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 364             iOS            Apple          Beef   On/Before June 30  ...
# 400             iOS           Orange          Beef     On/After July 1  ...
# 131             iOS           Orange          Beef   On/Before June 30  ...
# 81              iOS            Apple          Beef     On/After July 1  ...
# 155         Android           Orange          Pork   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 313                                Starbucks
# 187                                 Expresso
# 430                              iced coffee
# 509                                cold brew
# 472                                      NaN
# ..                                       ...
# 364                                Starbucks
# 400                           Regular coffee
# 131                               London Fog
# 81              Mango Dragon Fruit Refresher
# 155                   honey lemon ginger tea
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 313                           Netflix                       STAT 107
# 187                          Snapchat                None of them :)
# 430                         pinterest                            art
# 509                           twitter                        History
# 472                            TikTok                            NaN
# ..                                ...                            ...
# 364                            WeChat              Computer Science
# 400                         Pinterest                           Math
# 131                            Safari                        History
# 81                             TikTok                    Accountancy
# 155                            Google               Foreign Language
#
#     Who is your favorite singer? What is your favorite season?  \
# 313                One Direction                        Summer
# 187                       Mitski                        Winter
# 430                       capper                          fall
# 509                       MARINA                        spring
# 472                         Joji                        Spring
# ..                           ...                           ...
# 364                Taylor Swift                           Fall
# 400               Jean ken Johny                          Fall
# 131                   Ed Sheeran                        Summer
# 81                  Selena Gomez                        Winter
# 155                         AKMU                        Autumn
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 313                    gemini                          Valorant
# 187               Sagittarius                         Minecraft
# 430                  aquarius                 animal restaurant
# 509                    Taurus                               NaN
# 472                    Taurus                    Genshin Impact
# ..                        ...                               ...
# 364                  Aquarius                      Apex Legends
# 400                       Leo                Guilty gear strive
# 131                    Cancer                             FIFA
# 81                        Leo                          Fortnite
# 155                     Aries                        Sly Cooper
#
#     What is your favorite non-video game? What is your favorite food?  \
# 313                                Soccer                     Noodles
# 187                                 Chess                  Fried Rice
# 430                                 big 2                     noodles
# 509                              Rummikub                garlic bread
# 472                                   NaN                         NaN
# ..                                    ...                         ...
# 364                             Monopoly                 Lobster Rice
# 400                Cards against humanity                    Shawarma
# 131                              Monopoly                     Biryani
# 81                              Monopoly                 Cheese Bread
# 155                                 Mafia                    tomatoes
#
#     What's your favorite movie?
# 313                          83
# 187        Silence of the Lambs
# 430                  iron man 2
# 509                 Parent Trap
# 472           Crazy Rich Asians
# ..                          ...
# 364    The Shawshank Redemption
# 400            Top gun maverick
# 131         Inglorious Bastards
# 81                     Titanic
# 155          Memories of Murder
#
# [262 rows x 120 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=0.5)
control
# Out:
#              Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 491       Minghan  AL1                    2.0                    3.0
# 521  Shivam Patel  AYC                    1.0                    3.0
# 346       Michael  AYI                    1.0                    3.0
# 481          Abhi  AYA                    1.0                    5.0
# 486      julissa   lbd                    1.0                    5.0
# ..            ...  ...                    ...                    ...
# 446          John  AYA                    2.0                    3.0
# 268           Max  AYL                    1.0                    3.0
# 321            Ji  AYQ                    1.0                    3.0
# 391         Brian  AYK                    2.0                    3.0
# 53       Xiangyi   AYP                    1.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 491                                            0.5         Sierra Mist
# 521                                            0.5                 7UP
# 346                                            0.5                 7UP
# 481                                          2-Jan                 7UP
# 486                                          2-Jan                 7UP
# ..                                             ...                 ...
# 446                                          2-Jan                 NaN
# 268                                          2-Jan                 7UP
# 321                                            0.5                 7UP
# 391                                          2-Jan                 7UP
# 53                                           2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 491             iOS            Apple          Beef   On/Before June 30  ...
# 521             iOS            Apple           NaN   On/Before June 30  ...
# 346             iOS            Apple          Beef   On/Before June 30  ...
# 481             iOS           Orange           NaN     On/After July 1  ...
# 486             iOS           Orange          Beef   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 446             iOS           Orange          Pork   On/Before June 30  ...
# 268             iOS           Orange          Beef   On/Before June 30  ...
# 321             iOS           Orange          Beef     On/After July 1  ...
# 391             iOS            Apple          Beef   On/Before June 30  ...
# 53              iOS           Orange          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 491                                starbucks
# 521                          Don’t have one
# 346                                    Water
# 481                                   coffee
# 486                            iced milk tea
# ..                                       ...
# 446                                cold brew
# 268                               frappecino
# 321                                Starbucks
# 391                            Vanilla Latte
# 53                                     latte
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 491                            wechat                             IS
# 521                           Youtube                 World History
# 346                         Instagram                           Math
# 481                               NaN                            NaN
# 486                         pinterest                        English
# ..                                ...                            ...
# 446                            tiktok                       history
# 268                           stock x                           math
# 321                            Reddit                           Math
# 391                           Youtube                           Math
# 53                              weibo                     statistics
#
#     Who is your favorite singer? What is your favorite season?  \
# 491                   black pink                        summer
# 521                   Kumar Sanu                        Summer
# 346                   Kanye West                        Summer
# 481                          NaN                        summer
# 486                 frank ocean                         spring
# ..                           ...                           ...
# 446                jimmy buffet                        spring
# 268                        adele                        summer
# 321              Phoebe Bridgers                        Spring
# 391                      Changmo                          Fall
# 53                      Dua Lipa                        summer
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 491                    taurus                             Mario
# 521                 Aquarius                            FIFA 20
# 346                    Gemini                    Clash of Clans
# 481                       NaN                       arkham city
# 486                     aries                   clash of clans
# ..                        ...                               ...
# 446                   pisces                            madden
# 268                    Taurus                     Rocket league
# 321                   Scorpio                       Super Mario
# 391                     Aries                          Valorant
# 53                        idk                             none
#
#     What is your favorite non-video game? What is your favorite food?  \
# 491                                  card                chinese food
# 521                                 Chess                       Pizza
# 346                              Monopoly                   Hamburger
# 481                                   NaN                         NaN
# 486                           black jack                       wings
# ..                                    ...                         ...
# 446                      trivial pursuit                        sushi
# 268                                soccer                  quesadilla
# 321                              Monopoly                       Sushi
# 391                         King of Tokyo               Hamburg Steak
# 53                     wonderful homeland                     hot pot
#
#         What's your favorite movie?
# 491                       spiderman
# 521                Avengers Endgame
# 346  Star Wars - Return of the Jedi
# 481                 the dark knight
# 486                  the conjuring
# ..                              ...
# 446           shawshank redemption
# 268            Shawshank redemption
# 321                       Your Name
# 391                     Baby Driver
# 53                I don't have one
#
# [262 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#              Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 11         Ashley  AYN                    2.0                    5.0
# 13        Anvitha  AYP                    1.0                    5.0
# 14      Tianxiang  AYR                    1.0                    5.0
# 15         Steven  AYR                    1.0                    3.0
# 24          Brian  AYF                    1.0                    3.0
# ..            ...  ...                    ...                    ...
# 513           Jen  AYC                    2.0                    5.0
# 514          Bill  AYA                    1.0                    3.0
# 515        Faayez  AYT                    2.0                    5.0
# 516        Edward  AYQ                    1.0                    5.0
# 521  Shivam Patel  AYC                    1.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 11                                             0.5         Sierra Mist
# 13                                             0.5                 7UP
# 14                                           2-Jan                 7UP
# 15                                           2-Jan         Sierra Mist
# 24                                             0.5                 7UP
# ..                                             ...                 ...
# 513                                          2-Jan                 7UP
# 514                                          2-Jan                 7UP
# 515                                          2-Jan                 7UP
# 516                                            0.5         Sierra Mist
# 521                                            0.5                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 11              iOS            Apple          Beef   On/Before June 30  ...
# 13              iOS            Apple          Beef     On/After July 1  ...
# 14          Android           Orange          Pork     On/After July 1  ...
# 15              iOS            Apple          Beef   On/Before June 30  ...
# 24              iOS            Apple          Beef   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 513         Android            Apple          Pork     On/After July 1  ...
# 514             iOS           Orange          Beef   On/Before June 30  ...
# 515         Android            Apple          Beef   On/Before June 30  ...
# 516             iOS           Orange          Beef     On/After July 1  ...
# 521             iOS            Apple           NaN   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 11                         Caramel Macchiato
# 13                                any coffee
# 14                                 Starbucks
# 15                                Frappucino
# 24                                Cappuccino
# ..                                       ...
# 513                                     None
# 514                                 Starbuck
# 515                               Chai latte
# 516                                    Philz
# 521                          Don’t have one
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 11                             Sudoku                           Math
# 13                         instagram                            math
# 14                             Wechat                             CS
# 15                       Chipotle App                             CS
# 24                            Youtube                           Math
# ..                                ...                            ...
# 513                           Twitter                           Art
# 514                           Discord                           STAT
# 515                           Spotify                      Economics
# 516                       Xiaohongshu                        Finance
# 521                           Youtube                 World History
#
#     Who is your favorite singer? What is your favorite season?  \
# 11             Rex Orange County                          Fall
# 13                           NaN                          fall
# 14                          Gaga                        Spring
# 15                          Joji                          Fall
# 24                  Taylor Swift                        Summer
# ..                           ...                           ...
# 513                         ABBA                        Winter
# 514                 Taylor Swift                        Summer
# 515                  Arjit Singh                          Fall
# 516                   Bruno Mars                        summer
# 521                   Kumar Sanu                        Summer
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 11                     Cancer                    Stardew Valley
# 13                        leo                               NaN
# 14                     Monkey                               LOL
# 15                     Monkey                Leauge of Legends
# 24                     Gemini                        God of War
# ..                        ...                               ...
# 513              Sagittarius                              Zelda
# 514                    Taurus                         Minecraft
# 515                    Pisces                           Fifa 22
# 516               Sagittarius                I don't play games
# 521                 Aquarius                            FIFA 20
#
#     What is your favorite non-video game? What is your favorite food?  \
# 11                 Cards Against Humanity                        Soup
# 13                               monopoly                        poke
# 14                                   Ball                        Chip
# 15                          Any Card game                     Noodles
# 24                                    Uno                       Pizza
# ..                                    ...                         ...
# 513                                  Uno          Bacon Cheeseburger
# 514                                   Uno                       Salad
# 515                                Tennis                      Nihari
# 516                    I don't play games                    Barbecue
# 521                                 Chess                       Pizza
#
#     What's your favorite movie?
# 11                  Parent Trap
# 13              the parent trap
# 14                   Star Wars
# 15                 Interstellar
# 24                    Inception
# ..                          ...
# 513           Schindler's List
# 514                Interstellar
# 515        Pursuit of Happiness
# 516        Persuit of Happiness
# 521            Avengers Endgame
#
# [131 rows x 120 columns]

# %% [markdown]
# **Q: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# *(✏️ The code will result in some people being in both groups because we have two individual statements that randomly select people from the original set of data. The people who are in group 1 aren't removed out of the dataset when we randomly select for group 2. ✏️)*

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[~df.index.isin(treatment.index)]
control
# Out:
#        Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0    CA Ana  AL1                    2.0                    5.0
# 1    CA Ram  AYR                    2.0                    5.0
# 2    CA Xin  AYO                    1.0                    5.0
# 3     Lekha  AYH                    2.0                    2.0
# 4      Reni  AYD                    2.0                    5.0
# ..      ...  ...                    ...                    ...
# 507   Laiba  AYO                    1.0                    5.0
# 508   Julio  AYC                    2.0                    5.0
# 519    Bill  AYC                    1.0                    5.0
# 522   Colin  AYI                    1.0                    5.0
# 523    Evan  AYG                    2.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# 1                                            2-Jan                 7UP
# 2                                            2-Jan         Sierra Mist
# 3                                              0.5                 7UP
# 4                                            2-Jan                 7UP
# ..                                             ...                 ...
# 507                                            0.5                 7UP
# 508                                          2-Jan         Sierra Mist
# 519                                          2-Jan         Sierra Mist
# 522                                          2-Jan         Sierra Mist
# 523                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 0               iOS            Apple          Pork   On/Before June 30  ...
# 1               iOS            Apple           NaN     On/After July 1  ...
# 2               iOS            Apple          Beef   On/Before June 30  ...
# 3               iOS           Orange          Pork     On/After July 1  ...
# 4               iOS            Apple          Pork   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 507             iOS            Apple          Beef     On/After July 1  ...
# 508             iOS           Orange          Pork     On/After July 1  ...
# 519             iOS            Apple          Beef     On/After July 1  ...
# 522             iOS           Orange          Beef   On/Before June 30  ...
# 523         Android           Orange          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 0                                  Cold brew
# 1                               Black coffee
# 2                                  starbucks
# 3                        pumpkin spice latte
# 4                                      Mocha
# ..                                       ...
# 507                                Starbucks
# 508                             Black coffee
# 519                                      NaN
# 522                                      tea
# 523                                      Tea
#
#     What is your favorite mobile app?  What is your favorite subject?  \
# 0                            Snapchat                            Math
# 1                      Google chrome                      Mathematics
# 2                           Starbucks                      Psychology
# 3                             twitter               english (writing)
# 4                           Instagram                            Math
# ..                                ...                             ...
# 507                          Snapchat                              cs
# 508                         Instagram                         English
# 519                               NaN                             NaN
# 522                           YouTube                            Math
# 523                          Facebook  Probability and Measure Theory
#
#     Who is your favorite singer? What is your favorite season?  \
# 0                   Taylor Swift                          Fall
# 1                          TWICE                        Spring
# 2                  Five Exercuse                        Winter
# 3                   lana del rey                        autumn
# 4                  Mark kozelek                         Winter
# ..                           ...                           ...
# 507                 Taylor swift                          fall
# 508                 Layne Staley                          Fall
# 519                          NaN                           NaN
# 522                   The Weeknd                        Summer
# 523               Fredie Mercury                        Winter
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 0                      Piceis                         Minecraft
# 1                     Scorpio      Player Unkown's Battleground
# 2                    aquarius                              None
# 3                         leo                   animal crossing
# 4                    Aquarias                 Rainbow six siege
# ..                        ...                               ...
# 507                     libra                       fruit ninja
# 508                   Scorpio                            GTA IV
# 519                       NaN                               NaN
# 522                 Aquarious                     Rocket League
# 523                     Libra                         Uncharted
#
#     What is your favorite non-video game? What is your favorite food?  \
# 0                      Chutes and Ladders                      Yogurt
# 1                              Basketball                        Rice
# 2                                    None                       Eggs
# 3                                   catan                  tteokbokki
# 4                                   Catan                       Tacos
# ..                                    ...                         ...
# 507                              charades                     biryani
# 508                              Monopoly                    Pad Thai
# 519                                   NaN                         NaN
# 522                                 Poker                       Tacos
# 523                            Basketball             Eggs with bacon
#
#     What's your favorite movie?
# 0                             ?
# 1               The conjouring
# 2                       Flipped
# 3                   dune (2021)
# 4            End of Evangelion
# ..                          ...
# 507     Spiderman far from home
# 508                  The Matrix
# 519                         NaN
# 522                   Inception
# 523                Interstellar
#
# [262 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you??
# - If you did not fill out the "Hello Survey" then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead.  *(Those are the names we used in the `Name` column.)*

# %%
me = treatment[treatment.Name == "Sabarish"]
me
# Out:
#          Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 119  Sabarish  AYD                    2.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 119                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 119             iOS            Apple          Pork   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 119         Java Chip Frappacino - Starbucks
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 119                         Instagram                           Math
#
#     Who is your favorite singer? What is your favorite season?  \
# 119                   Bruno Mars                          Fall
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 119                     Virgo                             Forza
#
#     What is your favorite non-video game? What is your favorite food?  \
# 119                              Monopoly               Chicken Wings
#
#     What's your favorite movie?
# 119         Wolf of Wall Street
#
# [1 rows x 120 columns]

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q: Which group where you in -- treatment or control?**

# %% [markdown]
# *(✏️ Treatment ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking has us creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac=0.5)
df1_treatment
# Out:
#           Name       Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 152       Will       AYS                    2.0                    5.0
# 456         Mo       AYA                    2.0                    5.0
# 196       Yihe       AYD                    2.0                    3.0
# 252     Oliver       AYS                    1.0                    5.0
# 151  TA Daniel  AYB, AYD                    1.0                    5.0
# ..         ...       ...                    ...                    ...
# 269      Kevin       LBD                    1.0                    3.0
# 74       Alvin       AYT                    2.0                    5.0
# 335         SG       AYF                    2.0                    5.0
# 239       Jian       AYS                    1.0                    3.0
# 163     Corina       AYT                    1.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 152                                          2-Jan                 7UP
# 456                                          2-Jan                 7UP
# 196                                          2-Jan         Sierra Mist
# 252                                          2-Jan                 7UP
# 151                                          2-Jan         Sierra Mist
# ..                                             ...                 ...
# 269                                          2-Jan                 7UP
# 74                                           2-Jan         Sierra Mist
# 335                                            0.5                 7UP
# 239                                            0.5         Sierra Mist
# 163                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 152             iOS            Apple          Beef   On/Before June 30  ...
# 456             iOS           Orange          Beef   On/Before June 30  ...
# 196             iOS           Orange          Beef   On/Before June 30  ...
# 252             iOS           Orange          Beef     On/After July 1  ...
# 151         Android            Apple          Pork   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 269             iOS            Apple          Beef   On/Before June 30  ...
# 74          Android            Apple          Beef     On/After July 1  ...
# 335             iOS           Orange          Beef     On/After July 1  ...
# 239             iOS           Orange          Pork     On/After July 1  ...
# 163             iOS           Orange          Beef   On/Before June 30  ...
#
#               What is your favorite coffee shop drink?  \
# 152                                           Chai Tea
# 456                                         Chai latte
# 196                                          Americano
# 252                                         Chai Latte
# 151                                               Boba
# ..                                                 ...
# 269                                             Dunkin
# 74                              Green Tea Frappuccino
# 335  Iced Decaf Coffee with 2 Sweet n’ Low and Coco...
# 239                                        Dulce Latte
# 163                                          Cafe Kopi
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 152                          Transit                            Stat
# 456                            TikTok                       Business
# 196                           Spotify                           STAT
# 252                           Discord               Computer Science
# 151                           Discord            Atmospheric Science
# ..                                ...                            ...
# 269                          Snapchat               Computer Science
# 74                          Messenger               Computer Science
# 335                          Snapchat                            NaN
# 239                         instagram                           Math
# 163                           Twitter                           STAT
#
#     Who is your favorite singer? What is your favorite season?  \
# 152                        Adele                          Fall
# 456                     Dua Lipa                        Summer
# 196                    Blankpink                          Fall
# 252                   Billy Joel                        Spring
# 151                 Taylor Swift                       January
# ..                           ...                           ...
# 269                         None                          Fall
# 74                          BOL4                          Fall
# 335                          NaN                          Fall
# 239                         Lauv                        Winter
# 163                          NaN                          Fall
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 152                   Pisces                               Pong
# 456                    Pisces     Call of Duty : Modern Warfare
# 196                    Pisces          I don't play video games
# 252                     Libra                     Rocket League
# 151                    Pisces                      Chrono Cross
# ..                        ...                               ...
# 269                      None                             Fifa
# 74                      Virgo                 League of Legends
# 335                   Scorpio                         Overwatch
# 239               Sagittarius          I don't play video games
# 163                 Capricorn                               NaN
#
#     What is your favorite non-video game? What is your favorite food?  \
# 152                      Capture the Flag                   Poke Bowl
# 456                              Monopoly                     Biryani
# 196                              Peekaboo                Fried Noodle
# 252                                 Poker                      Salmon
# 151                         Secret Hitler                        Boba
# ..                                    ...                         ...
# 269                                 Poker                 Carne Asada
# 74                                  Chess                       Sushi
# 335                                 Poker                       Sushi
# 239                                 Dunno           Kimchi Pork Stew
# 163                      Would You Rather                    Gorditas
#
#     What's your favorite movie?
# 152            Fantastic Mr.Fox
# 456                   Parasite
# 196                   Inception
# 252                   Godfather
# 151                Finding Nemo
# ..                          ...
# 269                  Goodfellas
# 74                    Moneyball
# 335         The Florida Project
# 239             Five Feet Apart
# 163            A Marriage Story
#
# [238 rows x 120 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[~df1.index.isin(df1_treatment.index)]
df1_control
# Out:
#              Name   Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 3           Lekha   AYH                    2.0                    2.0
# 6        Esbeida    AYA                    2.0                    5.0
# 7         Jocelyn   AYS                    1.0                    5.0
# 8         Suvinay   AYP                    1.0                    5.0
# 10        Maxwell   AYJ                    1.0                    5.0
# ..            ...   ...                    ...                    ...
# 516        Edward   AYQ                    1.0                    5.0
# 517        Lauren   AYP                    1.0                    3.0
# 519          Bill   AYC                    1.0                    5.0
# 521  Shivam Patel   AYC                    1.0                    3.0
# 523          Evan   AYG                    2.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 3                                              0.5                 7UP
# 6                                            2-Jan                 7UP
# 7                                            2-Jan         Sierra Mist
# 8                                            2-Jan                 7UP
# 10                                           2-Jan                 7UP
# ..                                             ...                 ...
# 516                                            0.5         Sierra Mist
# 517                                          2-Jan                 7UP
# 519                                          2-Jan         Sierra Mist
# 521                                            0.5                 7UP
# 523                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 3               iOS           Orange          Pork     On/After July 1  ...
# 6               iOS           Orange          Beef     On/After July 1  ...
# 7               iOS           Orange          Beef     On/After July 1  ...
# 8           Android           Orange           NaN     On/After July 1  ...
# 10              iOS           Orange          Beef     On/After July 1  ...
# ..              ...              ...           ...                 ...  ...
# 516             iOS           Orange          Beef     On/After July 1  ...
# 517             iOS            Apple          Beef   On/Before June 30  ...
# 519             iOS            Apple          Beef     On/After July 1  ...
# 521             iOS            Apple           NaN   On/Before June 30  ...
# 523         Android           Orange          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 3                        pumpkin spice latte
# 6                       Iced vanilla coffee
# 7                Caramel crunch Frappuccino
# 8                                Frappuccino
# 10                  Peach green tea lemonade
# ..                                       ...
# 516                                    Philz
# 517                                      tea
# 519                                      NaN
# 521                          Don’t have one
# 523                                      Tea
#
#     What is your favorite mobile app?  What is your favorite subject?  \
# 3                             twitter               english (writing)
# 6                           Snapchat                             Math
# 7                             Spotify                         History
# 8                             Netflix                       Astronomy
# 10                            Spotify                            Math
# ..                                ...                             ...
# 516                       Xiaohongshu                         Finance
# 517                         instagram                         english
# 519                               NaN                             NaN
# 521                           Youtube                  World History
# 523                          Facebook  Probability and Measure Theory
#
#     Who is your favorite singer? What is your favorite season?  \
# 3                   lana del rey                        autumn
# 6                     The Weeknd                          Fall
# 7                 Olivia rodrigo                        Winter
# 8                Freddie Mercury                        Spring
# 10                        Eminem                          Fall
# ..                           ...                           ...
# 516                   Bruno Mars                        summer
# 517                ariana grande                        summer
# 519                          NaN                           NaN
# 521                   Kumar Sanu                        Summer
# 523               Fredie Mercury                        Winter
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 3                         leo                   animal crossing
# 6                  Capricorn                         Mario Kart
# 7                      Cancer         Link:  breath of the wild
# 8                 Sagitarrius                         Minecraft
# 10                    Scorpio                         Minecraft
# ..                        ...                               ...
# 516               Sagittarius                I don't play games
# 517                   taurus                       call of duty
# 519                       NaN                               NaN
# 521                 Aquarius                            FIFA 20
# 523                     Libra                         Uncharted
#
#     What is your favorite non-video game? What is your favorite food?  \
# 3                                   catan                  tteokbokki
# 6                 Cards Against Humanity                        Pasta
# 7                           Secret Hitler         Chicken noodle soup
# 8                                   Chess                Basmati Rice
# 10                               Monopoly                        Poke
# ..                                    ...                         ...
# 516                    I don't play games                    Barbecue
# 517                          flappy bird                       pasta
# 519                                   NaN                         NaN
# 521                                 Chess                       Pizza
# 523                            Basketball             Eggs with bacon
#
#     What's your favorite movie?
# 3                   dune (2021)
# 6                        Wall-E
# 7             Top gun maverick
# 8                  Interstellar
# 10                    Inception
# ..                          ...
# 516        Persuit of Happiness
# 517               the notebook
# 519                         NaN
# 521            Avengers Endgame
# 523                Interstellar
#
# [238 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac=0.5)
df2_treatment
# Out:
#          Name   Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 495     Aiden   AL1                    2.0                    3.0
# 114   Yuxiang   AYE                    1.0                    5.0
# 357    Rishab   AYG                    2.0                    3.0
# 221  Scarlett   AYJ                    2.0                    5.0
# 346   Michael   AYI                    1.0                    3.0
# 173  Jonathan   AYR                    2.0                    3.0
# 450    Andrew   AYA                    1.0                    3.0
# 233      Rama   AYL                    1.0                    5.0
# 332     Lanbu  BYOD                    1.0                    3.0
# 119  Sabarish   AYD                    2.0                    5.0
# 243      Evan   AYD                    1.0                    5.0
# 344  Anushree   AYH                    2.0                    5.0
# 283     Harry   AYE                    1.0                    3.0
# 32     Beomsu   AYD                    1.0                    5.0
# 99       Sean   AYS                    1.0                    3.0
# 77       Reva   AL1                    2.0                    3.0
# 325   Stephen   AYN                    1.0                    3.0
# 140    Andrew   AYF                    1.0                    3.0
# 436      Lizy   LBD                    2.0                    5.0
# 222     Grace   AYD                    1.0                    3.0
# 50      Yihao   AYS                    2.0                    5.0
# 208     Jimmy   AYA                    1.0                    3.0
# 58   Matthew    AYP                    2.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 495                                          2-Jan                 7UP
# 114                                          2-Jan                 7UP
# 357                                          2-Jan                 7UP
# 221                                            NaN                 NaN
# 346                                            0.5                 7UP
# 173                                            0.5                 7UP
# 450                                          2-Jan                 7UP
# 233                                          2-Jan                 7UP
# 332                                          2-Jan                 7UP
# 119                                          2-Jan                 7UP
# 243                                          2-Jan         Sierra Mist
# 344                                            0.5         Sierra Mist
# 283                                            0.5                 7UP
# 32                                           2-Jan         Sierra Mist
# 99                                           2-Jan                 7UP
# 77                                           2-Jan         Sierra Mist
# 325                                          2-Jan         Sierra Mist
# 140                                            0.5         Sierra Mist
# 436                                          2-Jan                 7UP
# 222                                          2-Jan                 7UP
# 50                                           2-Jan         Sierra Mist
# 208                                          2-Jan                 7UP
# 58                                             0.5                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 495         Android            Apple          Beef   On/Before June 30  ...
# 114         Android           Orange          Beef   On/Before June 30  ...
# 357             iOS           Orange          Beef     On/After July 1  ...
# 221             iOS           Orange          Beef     On/After July 1  ...
# 346             iOS            Apple          Beef   On/Before June 30  ...
# 173         Android            Apple          Beef     On/After July 1  ...
# 450             iOS            Apple          Beef     On/After July 1  ...
# 233             iOS           Orange          Pork   On/Before June 30  ...
# 332             iOS            Apple          Beef   On/Before June 30  ...
# 119             iOS            Apple          Pork   On/Before June 30  ...
# 243             iOS            Apple          Pork   On/Before June 30  ...
# 344             iOS           Orange          Pork   On/Before June 30  ...
# 283             iOS            Apple          Beef     On/After July 1  ...
# 32              iOS            Apple          Pork   On/Before June 30  ...
# 99              iOS            Apple          Beef     On/After July 1  ...
# 77          Android            Apple           NaN     On/After July 1  ...
# 325             iOS           Orange          Beef   On/Before June 30  ...
# 140         Android            Apple          Pork   On/Before June 30  ...
# 436             iOS            Apple          Beef   On/Before June 30  ...
# 222             iOS            Apple          Beef     On/After July 1  ...
# 50              iOS           Orange          Beef     On/After July 1  ...
# 208             iOS            Apple          Beef   On/Before June 30  ...
# 58              iOS           Orange          Beef   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 495                                java chip
# 114                                      NaN
# 357                             Black Coffee
# 221                            hot chocolate
# 346                                    Water
# 173                                Green Tea
# 450                                Starbucks
# 233                            Hot chocolate
# 332                                 hot coco
# 119         Java Chip Frappacino - Starbucks
# 243                                 Lemonade
# 344                               cold brew
# 283                                starbucks
# 32                                 americano
# 99                                 Starbucks
# 77          White chocolate creme frappucino
# 325                               Cappuccino
# 140                                   Coffee
# 436                               Iced Latte
# 222                                  dunkin
# 50                             Ice Americano
# 208                                    Latte
# 58                         Caramel Macchiato
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 495                          snapchat                        stat107
# 114                               NaN                             CS
# 357                            TikTok               Computer Science
# 221                               NaN                            NaN
# 346                         Instagram                           Math
# 173                         Instagram                             CS
# 450                           youtube               Computer Science
# 233                         Instagram                           Math
# 332                            Naruto                             PE
# 119                         Instagram                           Math
# 243                          Messages             Data Discovery 107
# 344                            BeReal                           Math
# 283                           youtube                        science
# 32                          Instagram              Computer Science
# 99                            YouTube                    Mathematics
# 77                          instagram                           STAT
# 325                            twitch                           Math
# 140                           Youtube                    Mathematics
# 436                          Tik Tok                          STATS
# 222                           youtube                           Math
# 50                    Little red book                          Music
# 208                              Uber                          STATS
# 58                       Google Maps                     Statistics
#
#     Who is your favorite singer? What is your favorite season?  \
# 495                        Oasis                        winter
# 114                          NaN                           NaN
# 357                 Taylor Swift                          Fall
# 221                          NaN                          fall
# 346                   Kanye West                        Summer
# 173                     Jay Chou                          Fall
# 450                   John Mayer                        winter
# 233                Ariana Grande                        Summer
# 332                       Capper                        Spring
# 119                   Bruno Mars                          Fall
# 243                        Tails                          Fall
# 344                    Baby Keem                          Fall
# 283                billie eilish                        spring
# 32                   Central cee                       Winter
# 99                       VIichan                        Winter
# 77                  Taylor Swift                        Spring
# 325                     Maroon 5                        Winter
# 140                  kurt cobain                          Fall
# 436              Phoebe Bridgers                       Spring
# 222                     Duo Lipa                        Summer
# 50                     Lady Gaga                        Autumn
# 208                  Alan Walker                          Fall
# 58                Frank Sinatra                         Winter
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 495                    taurus                            league
# 114                       NaN                               NaN
# 357                     Libra                         Minecraft
# 221                       NaN                               NaN
# 346                    Gemini                    Clash of Clans
# 173                       Leo                            Sudoku
# 450                       leo                          valorant
# 233                    Pisces                              FIFA
# 332                     Aries                            Naruto
# 119                     Virgo                             Forza
# 243                    Gemini         Super Smash Bros Ultimate
# 344                    Pisces                        Overcooked
# 283                    cancer                           fallout
# 32                     Sheep                          Valorant
# 99                Sagittarius                          Valorant
# 77                      Aries                          Mabinogi
# 325                    taurus                             GTA V
# 140                    Gemini                          Factorio
# 436                    Aries                        Smash Bros
# 222                     Virgo                             Zelda
# 50                      Virgo                             GTA 5
# 208                       PSC                         Fall Guys
# 58                     Gemini        Call of Duty: Black Ops II
#
#     What is your favorite non-video game? What is your favorite food?  \
# 495                              monopoly                  mac&cheese
# 114                                   NaN                         NaN
# 357                          Clash Royale                   Taco Bell
# 221                            boardgames                         NaN
# 346                              Monopoly                   Hamburger
# 173                              Monopoly                       Sushi
# 450                            basketball                      cheeze
# 233                         Secret Hitler                       Pizza
# 332                            basketball                       apple
# 119                              Monopoly               Chicken Wings
# 243                            Basketball          Chinese pork belly
# 344                               Contact              mac and cheese
# 283                         hide and seek                       chili
# 32                                  poker                       Pizza
# 99                               Monopoly                       Sushi
# 77                       Apples to Apples                     Noodles
# 325                              cashflow                      Fillet
# 140                                 Chess                   Ice cream
# 436                              Mancala              Sub Sandwiches
# 222                                   uno                    briscuit
# 50                                    NaN             Pineapple apple
# 208                                   UNO             Shrimp Dumpling
# 58                              My family                     Salmon
#
#          What's your favorite movie?
# 495                  Revenge of Sith
# 114                              NaN
# 357                               Us
# 221                              NaN
# 346   Star Wars - Return of the Jedi
# 173         The theory of everything
# 450              Night at the Museum
# 233                Avengers: Endgame
# 332                Naruto：Ninja road
# 119              Wolf of Wall Street
# 243  The Good, the Bad, and the Ugly
# 344                     Interstellar
# 283               batman dark knight
# 32                    Fast & Furious
# 99                    Ford v Ferrari
# 77                    Don't have one
# 325                    The Shawshank
# 140                  American Psycho
# 436                    Spider Man 3
# 222            avengers infinity war
# 50                        Fight Club
# 208         The Shawshank Redemption
# 58                             Mulan
#
# [23 rows x 120 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[~df2.index.isin(df2_treatment.index)]
df2_control
# Out:
#               Name   Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 79         Bernard   AYN                    1.0                    5.0
# 100          Kyle    AYJ                    1.0                    3.0
# 115         Jeremy   AYO                    1.0                    3.0
# 138           Sean   AYJ                    2.0                    3.0
# 154          Henri   LBD                    1.0                    5.0
# 158           Sota   AYT                    1.0                    5.0
# 198            Tom   AYD                    2.0                    5.0
# 225      zhenqiang   AYA                    1.0                    3.0
# 248         Ishaan   AYR                    1.0                    3.0
# 275      Seongwook   AYE                    2.0                    3.0
# 285  Daksheshkaran   AYP                    1.0                    5.0
# 286          JACKY   AYA                    1.0                    3.0
# 303       Pranavi    AYJ                    2.0                    5.0
# 310      Changrong   AYL                    1.0                    5.0
# 337            Ben   AYA                    1.0                    3.0
# 388          Tanya   AYC                    2.0                    3.0
# 399           Feng  Stat                    1.0                    3.0
# 421         Gianni   AYP                    1.0                    5.0
# 452         Luyang   AYB                    1.0                    5.0
# 467      Jeonghwan   AYL                    1.0                    3.0
# 468           jake   LBD                    2.0                    5.0
# 493          Yuang   AYF                    1.0                    3.0
# 500            Ray   AYO                    2.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 79                                           2-Jan                 7UP
# 100                                            0.5         Sierra Mist
# 115                                          2-Jan                 7UP
# 138                                          2-Jan         Sierra Mist
# 154                                          2-Jan         Sierra Mist
# 158                                          2-Jan                 7UP
# 198                                            0.5                 7UP
# 225                                          2-Jan         Sierra Mist
# 248                                          2-Jan                 7UP
# 275                                          2-Jan                 7UP
# 285                                            0.5                 7UP
# 286                                          2-Jan                 7UP
# 303                                          2-Jan                 7UP
# 310                                          2-Jan         Sierra Mist
# 337                                          2-Jan         Sierra Mist
# 388                                          2-Jan                 7UP
# 399                                          2-Jan                 7UP
# 421                                          2-Jan         Sierra Mist
# 452                                            0.5         Sierra Mist
# 467                                          2-Jan                 7UP
# 468                                          2-Jan                 7UP
# 493                                          2-Jan         Sierra Mist
# 500                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 79              iOS           Orange          Beef   On/Before June 30  ...
# 100             iOS            Apple          Beef   On/Before June 30  ...
# 115             iOS            Apple          Beef   On/Before June 30  ...
# 138             iOS            Apple          Beef     On/After July 1  ...
# 154             iOS            Apple          Beef   On/Before June 30  ...
# 158             iOS            Apple          Beef   On/Before June 30  ...
# 198             iOS           Orange          Beef   On/Before June 30  ...
# 225             iOS            Apple          Beef     On/After July 1  ...
# 248             iOS            Apple          Beef   On/Before June 30  ...
# 275         Android           Orange          Beef   On/Before June 30  ...
# 285             iOS            Apple          Pork   On/Before June 30  ...
# 286             iOS            Apple          Beef     On/After July 1  ...
# 303             iOS            Apple          Pork     On/After July 1  ...
# 310             iOS            Apple          Beef     On/After July 1  ...
# 337             iOS           Orange          Pork   On/Before June 30  ...
# 388             iOS           Orange          Pork   On/Before June 30  ...
# 399             iOS            Apple          Beef   On/Before June 30  ...
# 421             iOS            Apple          Beef   On/Before June 30  ...
# 452             iOS            Apple          Beef   On/Before June 30  ...
# 467             iOS           Orange          Beef     On/After July 1  ...
# 468             iOS            Apple          Beef     On/After July 1  ...
# 493             iOS            Apple          Beef     On/After July 1  ...
# 500         Android            Apple          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 79                                 Starbucks
# 100                            matcha latte
# 115                              Apple juice
# 138                                   coffee
# 154          Iced coffee with milk and sugar
# 158                                      NaN
# 198                                     Milk
# 225                                Starbucks
# 248                        Caramel Machiatto
# 275                           don't have one
# 285                            Hot Chocolate
# 286                                americano
# 303                           vanilla latte
# 310                                Starbucks
# 337                             black coffee
# 388                      iced vanilla latte
# 399                                       No
# 421          Iced Caramel Latte with OatMilk
# 452                                 Starbuck
# 467                                Starbucks
# 468                             black coffee
# 493                                Starbucks
# 500                                    water
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 79                           Snapchat                            P.E
# 100                        instagram                             NaN
# 115                           Youtube               Computer Science
# 138                           youtube                             cs
# 154                    Clash of Clans                           Stat
# 158                         Instagram                           Math
# 198                                QQ                     Psychology
# 225                            Wechat                           Math
# 248                            Tiktok               Computer Science
# 275                            dokkan                 Statistics 107
# 285                           Twitter                    Mathematics
# 286                             steam                             CS
# 303                          Netflix                     statistics
# 310                            wechat                     basketball
# 337                         instagram                     statistics
# 388                          snapchat                     philosophy
# 399                            Tiktok                           Math
# 421                            Tiktok                       Business
# 452                            TikTok                        history
# 467                           YouTube                             IS
# 468                           tic tok                           math
# 493                            Wechat                      Statistic
# 500                            Aidoku                       business
#
#     Who is your favorite singer? What is your favorite season?  \
# 79                          Joji                        Summer
# 100                        Keshi                          fall
# 115                          NaN                          Fall
# 138                   jonas blue                        autumn
# 154                   Bob Marley                        Winter
# 158                          NaN                        Summer
# 198                Mike Oldfield                        Spring
# 225                       Beyond                          Fall
# 248              Michael Jackson                        Spring
# 275               don't have one                        winter
# 285                 Taylor Swift                        Winter
# 286                           JB                        spring
# 303                   The Weeknd                       summer
# 310                       Eminem                        Summer
# 337                         yeat                          fall
# 388                 Lil uzi vert                        spring
# 399                     Jay Chou                          Fall
# 421               Kendrick Lamar                        Summer
# 452                     jay chou                        summer
# 467                       Eminem                        Winter
# 468                 Johnny cash                         spring
# 493                       Beyond                          Fall
# 500        Ikuta Lilas (YOASOBI)                        Winter
#
#         What is your Zodiac sign? What is your favorite video game?  \
# 79                         Pieces                Ghost of Tsushima
# 100                        gemini                        Pokemon go
# 115                        Taurus         Super Smash Bros Ultimate
# 138                        cancer                              apex
# 154                     Capricorn                  Feeding Frenzy 2
# 158                      Aquarius                        Smash Bros
# 198                        Taurus                         HighFleet
# 225                         sheep                              none
# 248                        Pisces                          Fortnite
# 275                        Tauras           Pokemon Black and White
# 285                        Pisces                           FIFA 22
# 286                         sheep                              csgo
# 303                       cancer                        Mario cart
# 310                       Scorpio                              Apex
# 337                        gemini                                2k
# 388                        pisces             call of duty zombies
# 399                            no                     Honor of King
# 421                        Gemini                             NBA2K
# 452  I do not know what is zodiac                              apex
# 467                        Cancer                            Tekken
# 468                           leo                         pga tour
# 493                         libra                              CSGO
# 500                        Cancer                     Rocket League
#
#     What is your favorite non-video game? What is your favorite food?  \
# 79                            spike ball?                mexican food
# 100                           basketball                          NaN
# 115                            Kingdomino                Cookie Dough
# 138                                 poker               fried noodles
# 154                                 Poker             Shrimp Cocktail
# 158                                   NaN                Cheeseburger
# 198                              Monopoly                     Sashimi
# 225                                Kungfu                        Rice
# 248                            Basketball                      Cereal
# 275                                 Poker                       curry
# 285                                   Uno              Chicken Burger
# 286                                  unio                       Buger
# 303                             monopoly                       sushi
# 310                         I am the boss                    hot dogs
# 337                            basketball             al pastor tacos
# 388                      sorry boardgame                 shrimp tacos
# 399                                soccer                       Rice
# 421                             Parchessi                Mexican Food
# 452                                   GTA                    dumpling
# 467                     League of Legends                        Meat
# 468                        texas hold em                        steak
# 493                                   NaN                       Sushi
# 500                                  golf                    Takoyaki
#
#     What's your favorite movie?
# 79                      Top Gun
# 100                    hobbits
# 115                Infinity War
# 138              now you see me
# 154                   Gladiator
# 158                  Glory Road
# 198    The Grand Budapest Hotel
# 225                    Iron man
# 248                    3 idiots
# 275              The lego movie
# 285                  Battleship
# 286              the green book
# 303          crazy rich asians
# 310                  green book
# 337                    superbad
# 388         catch me if you can
# 399                        Love
# 421                 Grown Ups 1
# 452                  iron man 2
# 467                       Tenet
# 468               happy gilmore
# 493                  Xiyangyang
# 500               Kimi no na wa
#
# [23 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`:

# %%
treatment = pd.concat([df1_treatment,df2_treatment])
treatment
# Out:
#           Name       Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 152       Will       AYS                    2.0                    5.0
# 456         Mo       AYA                    2.0                    5.0
# 196       Yihe       AYD                    2.0                    3.0
# 252     Oliver       AYS                    1.0                    5.0
# 151  TA Daniel  AYB, AYD                    1.0                    5.0
# ..         ...       ...                    ...                    ...
# 436       Lizy       LBD                    2.0                    5.0
# 222      Grace       AYD                    1.0                    3.0
# 50       Yihao       AYS                    2.0                    5.0
# 208      Jimmy       AYA                    1.0                    3.0
# 58    Matthew        AYP                    2.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 152                                          2-Jan                 7UP
# 456                                          2-Jan                 7UP
# 196                                          2-Jan         Sierra Mist
# 252                                          2-Jan                 7UP
# 151                                          2-Jan         Sierra Mist
# ..                                             ...                 ...
# 436                                          2-Jan                 7UP
# 222                                          2-Jan                 7UP
# 50                                           2-Jan         Sierra Mist
# 208                                          2-Jan                 7UP
# 58                                             0.5                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 152             iOS            Apple          Beef   On/Before June 30  ...
# 456             iOS           Orange          Beef   On/Before June 30  ...
# 196             iOS           Orange          Beef   On/Before June 30  ...
# 252             iOS           Orange          Beef     On/After July 1  ...
# 151         Android            Apple          Pork   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 436             iOS            Apple          Beef   On/Before June 30  ...
# 222             iOS            Apple          Beef     On/After July 1  ...
# 50              iOS           Orange          Beef     On/After July 1  ...
# 208             iOS            Apple          Beef   On/Before June 30  ...
# 58              iOS           Orange          Beef   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 152                                 Chai Tea
# 456                               Chai latte
# 196                                Americano
# 252                               Chai Latte
# 151                                     Boba
# ..                                       ...
# 436                               Iced Latte
# 222                                  dunkin
# 50                             Ice Americano
# 208                                    Latte
# 58                         Caramel Macchiato
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 152                          Transit                            Stat
# 456                            TikTok                       Business
# 196                           Spotify                           STAT
# 252                           Discord               Computer Science
# 151                           Discord            Atmospheric Science
# ..                                ...                            ...
# 436                          Tik Tok                          STATS
# 222                           youtube                           Math
# 50                    Little red book                          Music
# 208                              Uber                          STATS
# 58                       Google Maps                     Statistics
#
#     Who is your favorite singer? What is your favorite season?  \
# 152                        Adele                          Fall
# 456                     Dua Lipa                        Summer
# 196                    Blankpink                          Fall
# 252                   Billy Joel                        Spring
# 151                 Taylor Swift                       January
# ..                           ...                           ...
# 436              Phoebe Bridgers                       Spring
# 222                     Duo Lipa                        Summer
# 50                     Lady Gaga                        Autumn
# 208                  Alan Walker                          Fall
# 58                Frank Sinatra                         Winter
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 152                   Pisces                               Pong
# 456                    Pisces     Call of Duty : Modern Warfare
# 196                    Pisces          I don't play video games
# 252                     Libra                     Rocket League
# 151                    Pisces                      Chrono Cross
# ..                        ...                               ...
# 436                    Aries                        Smash Bros
# 222                     Virgo                             Zelda
# 50                      Virgo                             GTA 5
# 208                       PSC                         Fall Guys
# 58                     Gemini        Call of Duty: Black Ops II
#
#     What is your favorite non-video game? What is your favorite food?  \
# 152                      Capture the Flag                   Poke Bowl
# 456                              Monopoly                     Biryani
# 196                              Peekaboo                Fried Noodle
# 252                                 Poker                      Salmon
# 151                         Secret Hitler                        Boba
# ..                                    ...                         ...
# 436                              Mancala              Sub Sandwiches
# 222                                   uno                    briscuit
# 50                                    NaN             Pineapple apple
# 208                                   UNO             Shrimp Dumpling
# 58                              My family                     Salmon
#
#     What's your favorite movie?
# 152            Fantastic Mr.Fox
# 456                   Parasite
# 196                   Inception
# 252                   Godfather
# 151                Finding Nemo
# ..                          ...
# 436               Spider Man 3
# 222       avengers infinity war
# 50                   Fight Club
# 208    The Shawshank Redemption
# 58                        Mulan
#
# [261 rows x 120 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control,df2_control])
control
# Out:
#           Name   Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 3        Lekha   AYH                    2.0                    2.0
# 6     Esbeida    AYA                    2.0                    5.0
# 7      Jocelyn   AYS                    1.0                    5.0
# 8      Suvinay   AYP                    1.0                    5.0
# 10     Maxwell   AYJ                    1.0                    5.0
# ..         ...   ...                    ...                    ...
# 452     Luyang   AYB                    1.0                    5.0
# 467  Jeonghwan   AYL                    1.0                    3.0
# 468       jake   LBD                    2.0                    5.0
# 493      Yuang   AYF                    1.0                    3.0
# 500        Ray   AYO                    2.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 3                                              0.5                 7UP
# 6                                            2-Jan                 7UP
# 7                                            2-Jan         Sierra Mist
# 8                                            2-Jan                 7UP
# 10                                           2-Jan                 7UP
# ..                                             ...                 ...
# 452                                            0.5         Sierra Mist
# 467                                          2-Jan                 7UP
# 468                                          2-Jan                 7UP
# 493                                          2-Jan         Sierra Mist
# 500                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 3               iOS           Orange          Pork     On/After July 1  ...
# 6               iOS           Orange          Beef     On/After July 1  ...
# 7               iOS           Orange          Beef     On/After July 1  ...
# 8           Android           Orange           NaN     On/After July 1  ...
# 10              iOS           Orange          Beef     On/After July 1  ...
# ..              ...              ...           ...                 ...  ...
# 452             iOS            Apple          Beef   On/Before June 30  ...
# 467             iOS           Orange          Beef     On/After July 1  ...
# 468             iOS            Apple          Beef     On/After July 1  ...
# 493             iOS            Apple          Beef     On/After July 1  ...
# 500         Android            Apple          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 3                        pumpkin spice latte
# 6                       Iced vanilla coffee
# 7                Caramel crunch Frappuccino
# 8                                Frappuccino
# 10                  Peach green tea lemonade
# ..                                       ...
# 452                                 Starbuck
# 467                                Starbucks
# 468                             black coffee
# 493                                Starbucks
# 500                                    water
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 3                             twitter              english (writing)
# 6                           Snapchat                            Math
# 7                             Spotify                        History
# 8                             Netflix                      Astronomy
# 10                            Spotify                           Math
# ..                                ...                            ...
# 452                            TikTok                        history
# 467                           YouTube                             IS
# 468                           tic tok                           math
# 493                            Wechat                      Statistic
# 500                            Aidoku                       business
#
#     Who is your favorite singer? What is your favorite season?  \
# 3                   lana del rey                        autumn
# 6                     The Weeknd                          Fall
# 7                 Olivia rodrigo                        Winter
# 8                Freddie Mercury                        Spring
# 10                        Eminem                          Fall
# ..                           ...                           ...
# 452                     jay chou                        summer
# 467                       Eminem                        Winter
# 468                 Johnny cash                         spring
# 493                       Beyond                          Fall
# 500        Ikuta Lilas (YOASOBI)                        Winter
#
#         What is your Zodiac sign? What is your favorite video game?  \
# 3                             leo                   animal crossing
# 6                      Capricorn                         Mario Kart
# 7                          Cancer         Link:  breath of the wild
# 8                     Sagitarrius                         Minecraft
# 10                        Scorpio                         Minecraft
# ..                            ...                               ...
# 452  I do not know what is zodiac                              apex
# 467                        Cancer                            Tekken
# 468                           leo                         pga tour
# 493                         libra                              CSGO
# 500                        Cancer                     Rocket League
#
#     What is your favorite non-video game? What is your favorite food?  \
# 3                                   catan                  tteokbokki
# 6                 Cards Against Humanity                        Pasta
# 7                           Secret Hitler         Chicken noodle soup
# 8                                   Chess                Basmati Rice
# 10                               Monopoly                        Poke
# ..                                    ...                         ...
# 452                                   GTA                    dumpling
# 467                     League of Legends                        Meat
# 468                        texas hold em                        steak
# 493                                   NaN                       Sushi
# 500                                  golf                    Takoyaki
#
#     What's your favorite movie?
# 3                   dune (2021)
# 6                        Wall-E
# 7             Top gun maverick
# 8                  Interstellar
# 10                    Inception
# ..                          ...
# 452                  iron man 2
# 467                       Tenet
# 468               happy gilmore
# 493                  Xiyangyang
# 500               Kimi no na wa
#
# [261 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Blocking

# %% [markdown]
# **Q: In your own words, explain what blocking is and why it is useful to someone who has never taken a statistics course before! You can use what you did above as an example in your explanation if you'd like. Make sure to include what blocking is and why it is useful. Write at least three complete sentences to answer this question.**

# %% [markdown]
# *(✏️ Blocking is a method used to eliminate bias from small groups of data. The process involves categorizing the data into like-groups and then deciding who gets the treatment and control within each group. For instance, We can take a sample classroom and block the classmates based on age or gender to make the groups more alike and homogenous, eliminating bias and differences. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)

# %%
import pandas as pd
df = pd.read_csv("imdb_top_1000.csv")
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000    0.268531     0.494979
# Meta_score      0.268531    1.000000    -0.018507
# No_of_Votes     0.494979   -0.018507     1.000000

# %%
df_sixteen = df[df.Certificate == "16"]
df_sixteen
# Out:
#                                            Poster_Link    Series_Title  \
# 197  https://m.media-amazon.com/images/M/MV5BZGRkOG...  Koe no katachi
#
#     Released_Year Certificate  Runtime                     Genre  IMDB_Rating  \
# 197          2016          16  130 min  Animation, Drama, Family          8.1
#
#                                               Overview  Meta_score  \
# 197  A young man is ostracized by his classmates af...        78.0
#
#          Director       Star1         Star2     Star3       Star4  \
# 197  Naoko Yamada  Miyu Irino  Saori Hayami  Aoi Yûki  Kenshô Ono
#
#      No_of_Votes Gross
# 197        47708   NaN

# %%
df_sixteen.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating          NaN         NaN          NaN
# Meta_score           NaN         NaN          NaN
# No_of_Votes          NaN         NaN          NaN

# %%
df_sixteen.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_a = df[df.Certificate == "A"]
df_a
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 6    https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7    https://m.media-amazon.com/images/M/MV5BNDE4OT...
# ..                                                 ...
# 985  https://m.media-amazon.com/images/M/MV5BNDQ3Mz...
# 987  https://m.media-amazon.com/images/M/MV5BNDU1Mj...
# 989  https://m.media-amazon.com/images/M/MV5BYzZhOD...
# 993  https://m.media-amazon.com/images/M/MV5BYTE4YW...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 3      The Godfather: Part II          1974           A  202 min
# ...

# %%
df_a_best_meta = df_a.nlargest(10,"Meta_score")
df_a_best_meta
# Out:
#                                            Poster_Link  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 119  https://m.media-amazon.com/images/M/MV5BYTE4OD...
# 274  https://m.media-amazon.com/images/M/MV5BZmQzMD...
# 491  https://m.media-amazon.com/images/M/MV5BMTYzND...
# 49   https://m.media-amazon.com/images/M/MV5BNTQwND...
# 78   https://m.media-amazon.com/images/M/MV5BZWI3ZT...
# 447  https://m.media-amazon.com/images/M/MV5BNzk2M2...
# 543  https://m.media-amazon.com/images/M/MV5BNGUyYT...
# 19   https://m.media-amazon.com/images/M/MV5BYWZjMj...
# 215  https://m.media-amazon.com/images/M/MV5BMjExMT...
#
#                                           Series_Title Released_Year  \
# 1                                        The Godfather          1972
# 119                                            Vertigo          1958
# 274                                Fanny och Alexander          1982
# 491                                            Boyhood          2014
# ...

# %%
df_a_best_rating = df_a.nlargest(10,"IMDB_Rating")
df_a_best_rating
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 9   https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 12  https://m.media-amazon.com/images/M/MV5BOTQ5ND...
# 14  https://m.media-amazon.com/images/M/MV5BNzQzOT...
# 15  https://m.media-amazon.com/images/M/MV5BY2NkZj...
# 17  https://m.media-amazon.com/images/M/MV5BZjA0OW...
#
#                        Series_Title Released_Year Certificate  Runtime  \
# 0          The Shawshank Redemption          1994           A  142 min
# 1                     The Godfather          1972           A  175 min
# 3            The Godfather: Part II          1974           A  202 min
# 6                      Pulp Fiction          1994           A  154 min
# ...

# %%
df_a.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000    0.256749     0.692802
# Meta_score      0.256749    1.000000    -0.051293
# No_of_Votes     0.692802   -0.051293     1.000000

# %%
df_a.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_g = df[df.Certificate == "G"]
df_g
# Out:
#                                            Poster_Link  \
# 51   https://m.media-amazon.com/images/M/MV5BYjJiZj...
# 52   https://m.media-amazon.com/images/M/MV5BY2I4Mm...
# 120  https://m.media-amazon.com/images/M/MV5BZDRjNG...
# 228  https://m.media-amazon.com/images/M/MV5BNzE4ND...
# 282  https://m.media-amazon.com/images/M/MV5BMTg1MD...
# 401  https://m.media-amazon.com/images/M/MV5BMzE5MD...
# 422  https://m.media-amazon.com/images/M/MV5BMWMxND...
# 705  https://m.media-amazon.com/images/M/MV5BZTM1Zj...
# 819  https://m.media-amazon.com/images/M/MV5BN2Y0NW...
# 855  https://m.media-amazon.com/images/M/MV5BZDVhNz...
# 875  https://m.media-amazon.com/images/M/MV5BMjAxMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
#
#                    Series_Title Released_Year Certificate  Runtime  \
# 51                 Modern Times          1936           G   87 min
# 52                  City Lights          1931           G   87 min
# ...

# %%
df_g_best_meta = df_g.nlargest(10,"Meta_score")
df_g_best_meta
# Out:
#                                            Poster_Link  \
# 52   https://m.media-amazon.com/images/M/MV5BY2I4Mm...
# 120  https://m.media-amazon.com/images/M/MV5BZDRjNG...
# 51   https://m.media-amazon.com/images/M/MV5BYjJiZj...
# 875  https://m.media-amazon.com/images/M/MV5BMjAxMT...
# 401  https://m.media-amazon.com/images/M/MV5BMzE5MD...
# 855  https://m.media-amazon.com/images/M/MV5BZDVhNz...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 705  https://m.media-amazon.com/images/M/MV5BZTM1Zj...
# 422  https://m.media-amazon.com/images/M/MV5BMWMxND...
# 819  https://m.media-amazon.com/images/M/MV5BN2Y0NW...
#
#                    Series_Title Released_Year Certificate  Runtime  \
# 52                  City Lights          1931           G   87 min
# 120         Singin' in the Rain          1952           G  103 min
# 51                 Modern Times          1936           G   87 min
# 875                    Fantasia          1940           G  125 min
# ...

# %%
df_g_best_rating = df_g.nlargest(10,"IMDB_Rating")
df_g_best_rating

# %%
df_g.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000    0.537573     0.505575
# Meta_score      0.537573    1.000000     0.616486
# No_of_Votes     0.505575    0.616486     1.000000

# %%
df_g.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_pg = df[df.Certificate == "PG"]
df_pg
# Out:
#                                            Poster_Link  \
# 32   https://m.media-amazon.com/images/M/MV5BZjc4ND...
# 100  https://m.media-amazon.com/images/M/MV5BZTYwZW...
# 135  https://m.media-amazon.com/images/M/MV5BMWYwOT...
# 176  https://m.media-amazon.com/images/M/MV5BMjk3Yj...
# 178  https://m.media-amazon.com/images/M/MV5BN2IyNT...
# 219  https://m.media-amazon.com/images/M/MV5BMTQ2MD...
# 265  https://m.media-amazon.com/images/M/MV5BMjEzNj...
# 281  https://m.media-amazon.com/images/M/MV5BNmY0MW...
# 286  https://m.media-amazon.com/images/M/MV5BZmY4Yj...
# 304  https://m.media-amazon.com/images/M/MV5BMGVhNj...
# 389  https://m.media-amazon.com/images/M/MV5BMjIxND...
# 413  https://m.media-amazon.com/images/M/MV5BNjAzNz...
# 420  https://m.media-amazon.com/images/M/MV5BM2EzZm...
# 424  https://m.media-amazon.com/images/M/MV5BMTkyMT...
# 499  https://m.media-amazon.com/images/M/MV5BOGUwYT...
# 539  https://m.media-amazon.com/images/M/MV5BYzQ5Nj...
# ...

# %%
df_pg_best_meta = df_pg.nlargest(10,"Meta_score")
df_pg_best_meta
# Out:
#                                            Poster_Link  \
# 564  https://m.media-amazon.com/images/M/MV5BYjZjOT...
# 712  https://m.media-amazon.com/images/M/MV5BM2I1YW...
# 539  https://m.media-amazon.com/images/M/MV5BYzQ5Nj...
# 690  https://m.media-amazon.com/images/M/MV5BZjMyZm...
# 696  https://m.media-amazon.com/images/M/MV5BMDcxNj...
# 178  https://m.media-amazon.com/images/M/MV5BN2IyNT...
# 686  https://m.media-amazon.com/images/M/MV5BOTUwMD...
# 692  https://m.media-amazon.com/images/M/MV5BZWQzYj...
# 873  https://m.media-amazon.com/images/M/MV5BYzM3Yj...
# 286  https://m.media-amazon.com/images/M/MV5BZmY4Yj...
#
#                             Series_Title Released_Year Certificate  Runtime  \
# 564         The Adventures of Robin Hood          1938          PG  102 min
# 712                    Shadow of a Doubt          1943          PG  108 min
# 539  Le charme discret de la bourgeoisie          1972          PG  102 min
# ...

# %%
df_pg_best_rating = df_pg.nlargest(10,"IMDB_Rating")
df_pg_best_rating

# %%
df_pg.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000    0.087925     0.526091
# Meta_score      0.087925    1.000000     0.056508
# No_of_Votes     0.526091    0.056508     1.000000

# %%
df_pg.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_pg13 = df[df.Certificate == "PG-13"]
df_pg13
# Out:
#                                            Poster_Link  \
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...
# 89   https://m.media-amazon.com/images/M/MV5BN2JmMj...
# 227  https://m.media-amazon.com/images/M/MV5BMTUzOT...
# 235  https://m.media-amazon.com/images/M/MV5BZGJjYm...
# 358  https://m.media-amazon.com/images/M/MV5BMGRkZT...
# 365  https://m.media-amazon.com/images/M/MV5BMTc3Mj...
# 368  https://m.media-amazon.com/images/M/MV5BMDI5ZW...
# 438  https://m.media-amazon.com/images/M/MV5BOTA1Mj...
# 472  https://m.media-amazon.com/images/M/MV5BMjEzOD...
# 501  https://m.media-amazon.com/images/M/MV5BOGY1M2...
# 507  https://m.media-amazon.com/images/M/MV5BMWQ2Mj...
# 526  https://m.media-amazon.com/images/M/MV5BYWY3N2...
# 528  https://m.media-amazon.com/images/M/MV5BMWZiNW...
# 548  https://m.media-amazon.com/images/M/MV5BOTY0ZT...
# 588  https://m.media-amazon.com/images/M/MV5BMTcxNT...
# 595  https://m.media-amazon.com/images/M/MV5BMTU4ND...
# ...

# %%
df_pg13_best_meta = df_a.nlargest(10,"Meta_score")
df_pg13_best_meta
# Out:
#                                            Poster_Link  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 119  https://m.media-amazon.com/images/M/MV5BYTE4OD...
# 274  https://m.media-amazon.com/images/M/MV5BZmQzMD...
# 491  https://m.media-amazon.com/images/M/MV5BMTYzND...
# 49   https://m.media-amazon.com/images/M/MV5BNTQwND...
# 78   https://m.media-amazon.com/images/M/MV5BZWI3ZT...
# 447  https://m.media-amazon.com/images/M/MV5BNzk2M2...
# 543  https://m.media-amazon.com/images/M/MV5BNGUyYT...
# 19   https://m.media-amazon.com/images/M/MV5BYWZjMj...
# 215  https://m.media-amazon.com/images/M/MV5BMjExMT...
#
#                                           Series_Title Released_Year  \
# 1                                        The Godfather          1972
# 119                                            Vertigo          1958
# 274                                Fanny och Alexander          1982
# 491                                            Boyhood          2014
# ...

# %%
df_pg13_best_rating = df_pg13.nlargest(10,"IMDB_Rating")
df_pg13_best_rating

# %%
df_pg13.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000    0.393698    -0.017325
# Meta_score      0.393698    1.000000    -0.067076
# No_of_Votes    -0.017325   -0.067076     1.000000

# %%
df_pg13.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_r = df[df.Certificate == "R"]
df_r
# Out:
#                                            Poster_Link  \
# 24   https://m.media-amazon.com/images/M/MV5BZjhkMD...
# 38   https://m.media-amazon.com/images/M/MV5BOWRiZD...
# 40   https://m.media-amazon.com/images/M/MV5BZjA0MT...
# 74   https://m.media-amazon.com/images/M/MV5BMDdhOD...
# 75   https://m.media-amazon.com/images/M/MV5BMmQ2Mm...
# ..                                                 ...
# 952  https://m.media-amazon.com/images/M/MV5BMTA3OT...
# 957  https://m.media-amazon.com/images/M/MV5BNjA2ZD...
# 964  https://m.media-amazon.com/images/M/MV5BYTJlZm...
# 968  https://m.media-amazon.com/images/M/MV5BYjcxMz...
# 972  https://m.media-amazon.com/images/M/MV5BNjg5ZD...
#
#                        Series_Title Released_Year Certificate  Runtime  \
# 24              Saving Private Ryan          1998           R  169 min
# 38                      The Pianist          2002           R  150 min
# 40               American History X          1998           R  119 min
# ...

# %%
df_r_best_meta = df_r.nlargest(10,"Meta_score")
df_r_best_meta
# Out:
#                                            Poster_Link  \
# 720  https://m.media-amazon.com/images/M/MV5BMTU0OT...
# 195  https://m.media-amazon.com/images/M/MV5BNjgwNj...
# 74   https://m.media-amazon.com/images/M/MV5BMDdhOD...
# 478  https://m.media-amazon.com/images/M/MV5BMjA5Nz...
# 484  https://m.media-amazon.com/images/M/MV5BMGUyM2...
# 403  https://m.media-amazon.com/images/M/MV5BODA2Mj...
# 421  https://m.media-amazon.com/images/M/MV5BNmVjNz...
# 530  https://m.media-amazon.com/images/M/MV5BMTQ2MT...
# 895  https://m.media-amazon.com/images/M/MV5BYTYxZj...
# 24   https://m.media-amazon.com/images/M/MV5BZjhkMD...
#
#                           Series_Title Released_Year Certificate  Runtime  \
# 720                               Roma          2018           R  135 min
# 195  Portrait de la jeune fille en feu          2019           R  122 min
# 74                      Apocalypse Now          1979           R  147 min
# ...

# %%
df_r_best_rating = df_r.nlargest(10,"IMDB_Rating")
df_r_best_rating

# %%
df_r.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000    0.269048     0.513495
# Meta_score      0.269048    1.000000     0.075821
# No_of_Votes     0.513495    0.075821     1.000000

# %%
df_r.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_tv14 = df[df.Certificate == "TV-14"]
df_tv14
# Out:
#                                           Poster_Link          Series_Title  \
# 91  https://m.media-amazon.com/images/M/MV5BOGE3N2...  Miracle in cell NO.7
#
#    Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# 91          2019       TV-14  132 min  Drama          8.3
#
#                                              Overview  Meta_score  \
# 91  A story of love between a mentally-ill father ...         NaN
#
#               Director               Star1                 Star2  \
# 91  Mehmet Ada Öztekin  Aras Bulut Iynemli  Nisa Sofiya Aksongur
#
#            Star3               Star4  No_of_Votes Gross
# 91  Deniz Baysal  Celile Toyon Uysal        33935   NaN

# %%
df_tv14.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating          NaN         NaN          NaN
# Meta_score           NaN         NaN          NaN
# No_of_Votes          NaN         NaN          NaN

# %%
df_tv14.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_ma = df[df.Certificate == "MA"]
df_ma
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %%
df_ma_best_rating = df_ma.nlargest(10,"IMDB_Rating")
df_ma_best_rating

# %%
df_ma.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating          NaN         NaN          NaN
# Meta_score           NaN         NaN          NaN
# No_of_Votes          NaN         NaN          NaN

# %%
df_ma.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_tvpg = df[df.Certificate == "TV-PG"]
df_tvpg
# Out:
#                                            Poster_Link       Series_Title  \
# 349  https://m.media-amazon.com/images/M/MV5BMTQ0Mz...     Darbareye Elly
# 460  https://m.media-amazon.com/images/M/MV5BYmFlOW...       The Thin Man
# 876  https://m.media-amazon.com/images/M/MV5BYjllMm...  The Invisible Man
#
#     Released_Year Certificate  Runtime                   Genre  IMDB_Rating  \
# 349          2009       TV-PG  119 min          Drama, Mystery          8.0
# 460          1934       TV-PG   91 min  Comedy, Crime, Mystery          8.0
# 876          1933       TV-PG   71 min          Horror, Sci-Fi          7.7
#
#                                               Overview  Meta_score  \
# 349  The mysterious disappearance of a kindergarten...        87.0
# 460  Former detective Nick Charles and his wealthy ...        86.0
# 876  A scientist finds a way of becoming invisible,...        87.0
#
#            Director                Star1            Star2               Star3  \
# ...

# %%
df_tvpg_best_rating = df_tvpg.nlargest(10,"IMDB_Rating")
df_tvpg_best_rating
# Out:
#                                            Poster_Link       Series_Title  \
# 349  https://m.media-amazon.com/images/M/MV5BMTQ0Mz...     Darbareye Elly
# 460  https://m.media-amazon.com/images/M/MV5BYmFlOW...       The Thin Man
# 876  https://m.media-amazon.com/images/M/MV5BYjllMm...  The Invisible Man
#
#     Released_Year Certificate  Runtime                   Genre  IMDB_Rating  \
# 349          2009       TV-PG  119 min          Drama, Mystery          8.0
# 460          1934       TV-PG   91 min  Comedy, Crime, Mystery          8.0
# 876          1933       TV-PG   71 min          Horror, Sci-Fi          7.7
#
#                                               Overview  Meta_score  \
# 349  The mysterious disappearance of a kindergarten...        87.0
# 460  Former detective Nick Charles and his wealthy ...        86.0
# 876  A scientist finds a way of becoming invisible,...        87.0
#
#            Director                Star1            Star2               Star3  \
# ...

# %%
df_tvpg.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000   -0.500000     0.316649
# Meta_score     -0.500000    1.000000     0.663137
# No_of_Votes     0.316649    0.663137     1.000000

# %%
df_tvpg.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_ua = df[df.Certificate == "UA"]
df_ua
# Out:
#                                            Poster_Link  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 11   https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 13   https://m.media-amazon.com/images/M/MV5BZGMxZT...
# 16   https://m.media-amazon.com/images/M/MV5BYmU1ND...
# ..                                                 ...
# 960  https://m.media-amazon.com/images/M/MV5BMzk1Mm...
# 970  https://m.media-amazon.com/images/M/MV5BMTQxND...
# 975  https://m.media-amazon.com/images/M/MV5BMjE0OD...
# 981  https://m.media-amazon.com/images/M/MV5BNWQ4MG...
# 983  https://m.media-amazon.com/images/M/MV5BYTU2MW...
#
#                                        Series_Title Released_Year Certificate  \
# 2                                   The Dark Knight          2008          UA
# 8                                         Inception          2010          UA
# ...

# %%
df_ua_best_meta = df_ua.nlargest(10,"Meta_score")
df_ua_best_meta
# Out:
#                                            Poster_Link           Series_Title  \
# 124  https://m.media-amazon.com/images/M/MV5BYjBiOT...           Citizen Kane
# 423  https://m.media-amazon.com/images/M/MV5BODFlYz...         Il conformista
# 150  https://m.media-amazon.com/images/M/MV5BMTU3OD...        Pan's Labyrinth
# 580  https://m.media-amazon.com/images/M/MV5BMTYxMj...  Manchester by the Sea
# 745  https://m.media-amazon.com/images/M/MV5BNjE5Mz...                Gravity
# 748  https://m.media-amazon.com/images/M/MV5BOGUyZD...     The Social Network
# 483  https://m.media-amazon.com/images/M/MV5BMTk1NT...                  Amour
# 573  https://m.media-amazon.com/images/M/MV5BN2YyZj...                Dunkirk
# 645  https://m.media-amazon.com/images/M/MV5BNDdhMz...        Wo hu cang long
# 467  https://m.media-amazon.com/images/M/MV5BNDk3NT...   Call Me by Your Name
#
#     Released_Year Certificate  Runtime                       Genre  \
# ...

# %%
df_ua_best_rating = df_ua.nlargest(10,"IMDB_Rating")
df_ua_best_rating
# Out:
#                                           Poster_Link  \
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 13  https://m.media-amazon.com/images/M/MV5BZGMxZT...
# 16  https://m.media-amazon.com/images/M/MV5BYmU1ND...
# 21  https://m.media-amazon.com/images/M/MV5BZjdkOT...
# 29  https://m.media-amazon.com/images/M/MV5BNzVlY2...
# 35  https://m.media-amazon.com/images/M/MV5BMTYxND...
# 39  https://m.media-amazon.com/images/M/MV5BMDliMm...
# 55  https://m.media-amazon.com/images/M/MV5BY2FiMT...
#
#                                       Series_Title Released_Year Certificate  \
# 2                                  The Dark Knight          2008          UA
# 8                                        Inception          2010          UA
# 11                                    Forrest Gump          1994          UA
# ...

# %%
df_ua.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000    0.153893     0.493042
# Meta_score      0.153893    1.000000     0.097384
# No_of_Votes     0.493042    0.097384     1.000000

# %%
df_ua.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
df_au = df[df.Certificate == "U/A"]
df_au
# Out:
#                                            Poster_Link Series_Title  \
# 878  https://m.media-amazon.com/images/M/MV5BMjIwOT...    Searching
#
#     Released_Year Certificate  Runtime                     Genre  IMDB_Rating  \
# 878          2018         U/A  102 min  Drama, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 878  After his teenage daughter goes missing, a des...        71.0
#
#             Director     Star1          Star2       Star3        Star4  \
# 878  Aneesh Chaganty  John Cho  Debra Messing  Joseph Lee  Michelle La
#
#      No_of_Votes       Gross
# 878       140840  26,020,957

# %%
df_au.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating          NaN         NaN          NaN
# Meta_score           NaN         NaN          NaN
# No_of_Votes          NaN         NaN          NaN

# %%
df_au.plot.scatter(x='IMDB_Rating',y='Meta_score')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Meta_score'>

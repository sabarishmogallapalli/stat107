# %% [markdown]
# <h1 style="text-align: center">
# <div style="color: #DD3403; font-size: 60%">Data Science DISCOVERY MicroProject #1</div>
# <span style="">MicroProject: United States Congress</span>
# <div style="font-size: 60%;"><a href="https://discovery.cs.illinois.edu/microproject/01-us-congress/">https://discovery.cs.illinois.edu/microproject/01-us-congress/</a></div>
# </h1>
#
# <hr style="color: #DD3403;">
#
# ## Introduction
#
# In this microproject, you will use Exploratory Data Analysis (EDA) techniques and the `groupby` function to find various statistics about the current legislators in the United States Congress.  Let's nerd out!

# %% [markdown]
# ## Dataset: "congress-legislators"
#
# The [@unitedstates project](https://theunitedstates.io/) maintains various high-quality datasets about the United States government.  Specifically, the `congress-legislators` dataset every member "of the United States Congress (1789-Present), congressional committees (1973-Present), committee membership (current only), and presidents and vice presidents of the United States in YAML, JSON, and CSV format."
#
# The URL for the CSV dataset is:
# ```
# https://theunitedstates.io/congress-legislators/legislators-current.csv
# ```
#
# Load the dataset into a DataFrame called `df`:

# %%
import pandas as pd

df = pd.read_csv("https://theunitedstates.io/congress-legislators/legislators-current.csv")

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 1: Splitting The House of Representatives and The Senate
#
# In this dataset, each row is one member of Congress.  The United States Congress is bicameral, being made up of both the House of Representatives and the Senate.  In the dataset:
#
# - Representatives in the House of Representatives represent a district, which is encoded in the `district` column.  (Senators will have the `district` column blank.)
# - Senators are elected for six years, with one-third of the senators up for election every two years.  The `senate_class` denotes which election class a senator is in.  (Representatives will have the `senate_class` column blank.)
#
# Create two new DataFrames, `df_house` and `df_senate`, that contain members of the House of Representatives and the Senate:

# %%
df_house = df[(df.district >= 0) & (df.district <=53)]
df_house
# Out:
#                last_name first_name middle_name suffix nickname  \
# 28              Aderholt     Robert          B.    NaN      NaN
# 30                  Bass      Karen         NaN    NaN      NaN
# 32             Bilirakis        Gus          M.    NaN      NaN
# 33                Bishop    Sanford          D.    Jr.      NaN
# 35            Blumenauer       Earl         NaN    NaN      NaN
# ..                   ...        ...         ...    ...      ...
# 531  Cherfilus-McCormick     Sheila         NaN    NaN      NaN
# 532               Conway     Connie         NaN    NaN      NaN
# 533               Flores      Mayra         NaN    NaN      NaN
# 534                Flood       Mike         NaN    NaN      NaN
# 535              Finstad       Brad         NaN    NaN      NaN
#
#                       full_name    birthday gender type state  ...  \
# 28           Robert B. Aderholt  1965-07-22      M  rep    AL  ...
# 30                   Karen Bass  1953-10-03      F  rep    CA  ...
# 32             Gus M. Bilirakis  1963-02-08      M  rep    FL  ...
# 33       Sanford D. Bishop, Jr.  1947-02-04      M  rep    GA  ...
# 35              Earl Blumenauer  1948-08-16      M  rep    OR  ...
# ..                          ...         ...    ...  ...   ...  ...
# 531  Sheila Cherfilus-McCormick  1979-01-25      F  rep    FL  ...
# 532               Connie Conway  1950-09-25      F  rep    CA  ...
# 533                Mayra Flores  1986-01-01      F  rep    TX  ...
# 534                         NaN  1975-02-23      M  rep    NE  ...
# 535                         NaN  1976-05-30      M  rep    MN  ...
#
#      opensecrets_id  lis_id    fec_ids   cspan_id govtrack_id votesmart_id  \
# 28        N00003028     NaN  H6AL04098    45516.0      400004        441.0
# 30        N00031877     NaN  H0CA33117    62502.0      412404      28963.0
# 32        N00027462     NaN  H6FL09070  1022873.0      412250      17318.0
# 33        N00002674     NaN  H2GA02031    26194.0      400030      26817.0
# 35        N00007727     NaN  H6OR03064    43809.0      400033        367.0
# ..              ...     ...        ...        ...         ...          ...
# 531             NaN     NaN  H8FL20032        NaN      456865          NaN
# 532             NaN     NaN  H2CA22231        NaN      456866          NaN
# 533             NaN     NaN  H2TX34113        NaN      456867          NaN
# 534             NaN     NaN  H2NE01118        NaN      456868          NaN
# 535             NaN     NaN  H2MN01223        NaN      456869          NaN
#
#          ballotpedia_id washington_post_id icpsr_id  \
# 28   Robert B. Aderholt                NaN  29701.0
# 30           Karen Bass                NaN  21110.0
# 32     Gus M. Bilirakis                NaN  20758.0
# 33   Sanford Bishop Jr.                NaN  29339.0
# 35      Earl Blumenauer                NaN  29588.0
# ..                  ...                ...      ...
# 531                 NaN                NaN      NaN
# 532       Connie Conway                NaN      NaN
# 533                 NaN                NaN      NaN
# 534          Mike Flood                NaN      NaN
# 535        Brad Finstad                NaN      NaN
#
#                    wikipedia_id
# 28              Robert Aderholt
# 30                   Karen Bass
# 32                Gus Bilirakis
# 33               Sanford Bishop
# 35              Earl Blumenauer
# ..                          ...
# 531  Sheila Cherfilus-McCormick
# 532               Connie Conway
# 533                Mayra Flores
# 534     Mike Flood (politician)
# 535                Brad Finstad
#
# [436 rows x 34 columns]

# %%
df_senate = df[df["senate_class"] >= 0]
df_senate
# Out:
#         last_name first_name middle_name suffix nickname  \
# 0           Brown    Sherrod         NaN    NaN      NaN
# 1        Cantwell      Maria         NaN    NaN      NaN
# 2          Cardin   Benjamin          L.    NaN      NaN
# 3          Carper     Thomas     Richard    NaN      NaN
# 4           Casey     Robert          P.    Jr.      Bob
# ..            ...        ...         ...    ...      ...
# 462  Hickenlooper       John      Wright    NaN      NaN
# 463       Hagerty       Bill     Francis    NaN      NaN
# 521       Padilla  Alejandro         NaN    NaN     Alex
# 522        Ossoff        Jon         NaN    NaN      NaN
# 523       Warnock    Raphael    Gamaliel    NaN      NaN
#
#                 full_name    birthday gender type state  ...  opensecrets_id  \
# 0           Sherrod Brown  1952-11-09      M  sen    OH  ...       N00003535
# 1          Maria Cantwell  1958-10-13      F  sen    WA  ...       N00007836
# 2      Benjamin L. Cardin  1943-10-05      M  sen    MD  ...       N00001955
# 3        Thomas R. Carper  1947-01-23      M  sen    DE  ...       N00012508
# 4    Robert P. Casey, Jr.  1960-04-13      M  sen    PA  ...       N00027503
# ..                    ...         ...    ...  ...   ...  ...             ...
# 462  John W. Hickenlooper  1952-02-07      M  sen    CO  ...       N00044206
# 463          Bill Hagerty  1959-08-14      M  sen    TN  ...       N00045369
# 521          Alex Padilla  1973-03-22      M  sen    CA  ...       N00047888
# 522            Jon Ossoff  1987-02-16      M  sen    GA  ...       N00040675
# 523    Raphael G. Warnock  1969-07-23      M  sen    GA  ...       N00046489
#
#      lis_id              fec_ids cspan_id govtrack_id votesmart_id  \
# 0      S307  H2OH13033,S6OH00163   5051.0      400050      27018.0
# 1      S275  S8WA00194,H2WA01054  26137.0      300018      27122.0
# 2      S308  H6MD03177,S6MD03177   4004.0      400064      26888.0
# 3      S277            S8DE00079    663.0      300019      22421.0
# 4      S309            S6PA00217  47036.0      412246       2541.0
# ..      ...                  ...      ...         ...          ...
# 462    S408            S0CO00575      NaN      456797          NaN
# 463    S407            S0TN00169      NaN      456798     128466.0
# 521    S413            S2CA00955      NaN      456856          NaN
# 522    S414  H8GA06195,S8GA00180      NaN      456857          NaN
# 523    S415            S0GA00559      NaN      456858          NaN
#
#         ballotpedia_id washington_post_id icpsr_id               wikipedia_id
# 0        Sherrod Brown                NaN  29389.0              Sherrod Brown
# 1       Maria Cantwell                NaN  39310.0             Maria Cantwell
# 2           Ben Cardin                NaN  15408.0                 Ben Cardin
# 3           Tom Carper                NaN  15015.0                 Tom Carper
# 4       Bob Casey, Jr.                NaN  40703.0              Bob Casey Jr.
# ..                 ...                ...      ...                        ...
# 462  John Hickenlooper                NaN      NaN          John Hickenlooper
# 463       Bill Hagerty                NaN      NaN  Bill Hagerty (politician)
# 521       Alex Padilla                NaN      NaN               Alex Padilla
# 522         Jon Ossoff                NaN      NaN                 Jon Ossoff
# 523    Raphael Warnock                NaN      NaN            Raphael Warnock
#
# [100 rows x 34 columns]

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 2: Find the Controlling Party of the House of Representatives
#
# In each body of Congress, the "controlling party" is the party that has the majority of the members.  Using `groupby`, create a DataFrame `df_house_party` that counts the number of members in each political party in the House of Representatives:

# %%
df_house_party = df.groupby("party").agg("count").reset_index()
df_house_party
# Out:
#          party  last_name  first_name  middle_name  suffix  nickname  \
# 0     Democrat        271         271          129      11        20
# 1  Independent          2           2            1       1         1
# 2   Republican        263         263          114       6        20
#
#    full_name  birthday  gender  type  ...  opensecrets_id  lis_id  fec_ids  \
# 0        271       271     271   271  ...             269      48      271
# 1          2         2       2     2  ...               2       2        2
# 2        261       263     263   263  ...             258      50      263
#
#    cspan_id  govtrack_id  votesmart_id  ballotpedia_id  washington_post_id  \
# 0       200          271           245             251                   0
# 1         2            2             2               2                   0
# 2       173          263           220             234                   0
#
#    icpsr_id  wikipedia_id
# 0       243           271
# 1         2             2
# 2       207           262
#
# [3 rows x 34 columns]

# %% [markdown]
# ### Puzzle 2 Analysis: How many Democrats and Republicans in the House?
#
# Using the result above, fill out the following cell with the number of Democrats and Republications:

# %%
democrats_in_house = 271
republications_in_house = 263

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 3: Find the Youngest Member of each Party in the House of Representatives
#
# In the House of Representatives, who is the youngest member Democrat and who is the youngest Republican?

# %%
# ...feel free to add additional Python "Code Cells" if you need to!

df_house = df[df["type"] == "rep"]
df_democrat = df_house[df_house["party"] == "Democrat"]
df_youngest_democrat = df_democrat[df_democrat["birthday"] == "1989-10-13"]
df_youngest_democrat
# Out:
#          last_name  first_name middle_name suffix nickname  \
# 417  Ocasio-Cortez  Alexandria         NaN    NaN      NaN
#
#                     full_name    birthday gender type state  ...  \
# 417  Alexandria Ocasio-Cortez  1989-10-13      F  rep    NY  ...
#
#      opensecrets_id  lis_id    fec_ids cspan_id govtrack_id votesmart_id  \
# 417       N00041162     NaN  H8NY15148      NaN      412804     180416.0
#
#                ballotpedia_id washington_post_id icpsr_id  \
# 417  Alexandria Ocasio-Cortez                NaN  21949.0
#
#                  wikipedia_id
# 417  Alexandria Ocasio-Cortez
#
# [1 rows x 34 columns]

# %%
df_house = df[df["type"] == "rep"]
df_republican = df_house[df_house["party"] == "Republican"]
df_youngest_republican = df_republican[df_republican["birthday"] == "1995-08-01"]
df_youngest_republican
# Out:
#     last_name first_name middle_name suffix nickname         full_name  \
# 498  Cawthorn    Madison         NaN    NaN      NaN  Madison Cawthorn
#
#        birthday gender type state  ...  opensecrets_id  lis_id    fec_ids  \
# 498  1995-08-01      M  rep    NC  ...       N00046252     NaN  H0NC11233
#
#     cspan_id govtrack_id votesmart_id    ballotpedia_id washington_post_id  \
# 498      NaN      456833          NaN  Madison Cawthorn                NaN
#
#     icpsr_id      wikipedia_id
# 498      NaN  Madison Cawthorn
#
# [1 rows x 34 columns]

# %% [markdown]
# ### Puzzle 3 Analysis: How many Democrats and Republicans in the House?
#
# Using the result above, provide the **full name** of the youngest Democrat and Republican:

# %%
youngest_democrat_in_house = "Alexandria Ocasio-Cortez"
youngest_republican_in_house = "Madison Cawthorn"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## 🔬 Microproject Checkpoint Tests 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for the microproject.
# - If this cell runs without any error in the output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cells, make changes, and RE-RUN your code and then this cell.

tada = "\N{PARTY POPPER}"
R = -1
D = R - 1

assert( len(df) > 500 )
assert( len(df_senate) <= 100 )
assert( len(df_house) == len(df) - len(df_senate) )
print(f"{tada} Puzzle 1: All Tests Passed! {tada}")

assert(len(df_house_party) == 2)
assert((df_house_party.index[0] == "Democrat" or df_house_party.index[0] == "Republican" or "party" in df.columns.tolist()))
assert(len(df) - len(df_senate) - df_house.value_counts(df.columns.tolist()[12])[df.sort_values(df.columns.tolist()[6]).iloc[R][df.columns.tolist()[12]]] == democrats_in_house)
assert(len(df) - len(df_senate) - df_house.value_counts(df.columns.tolist()[12])[df.sort_values(df.columns.tolist()[6]).iloc[D][df.columns.tolist()[12]]] == republications_in_house)
print(f"{tada} Puzzle 2: All Tests Passed! {tada}")

assert(df.sort_values(df.columns.tolist()[6]).iloc[D][df.columns.tolist()[5]] == youngest_democrat_in_house)
assert(df.sort_values(df.columns.tolist()[6]).iloc[R][df.columns.tolist()[5]] == youngest_republican_in_house)
print(f"{tada} Puzzle 3: All Tests Passed! {tada}")

print(f"{tada}{tada} All Tests Passed! {tada}{tada}")
# Out:
# 🎉 Puzzle 1: All Tests Passed! 🎉
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/sabarishmogallapalli/Desktop/stat107/sm108/01-microproject-us-congress/01-microproject-us-congress.ipynb Cell 21 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/Users/sabarishmogallapalli/Desktop/stat107/sm108/01-microproject-us-congress/01-microproject-us-congress.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a> assert(len(df_house_party) == 2)
#      <a href='vscode-notebook-cell:/Users/sabarishmogallapalli/Desktop/stat107/sm108/01-microproject-us-congress/01-microproject-us-congress.ipynb#X25sZmlsZQ%3D%3D?line=15'>16</a> assert((df_house_party.index[0] == "Democrat" or df_house_party.index[0] == "Republican" or "party" in df.columns.tolist()))
# ---> <a href='vscode-notebook-cell:/Users/sabarishmogallapalli/Desktop/stat107/sm108/01-microproject-us-congress/01-microproject-us-congress.ipynb#X25sZmlsZQ%3D%3D?line=16'>17</a> assert(len(df) - len(df_senate) - df_house.value_counts(df.columns.tolist()[12])[df.sort_values(df.columns.tolist()[6]).iloc[R][df.columns.tolist()[12]]] == democrats_in_house)
#      <a href='vscode-notebook-cell:/Users/sabarishmogallapalli/Desktop/stat107/sm108/01-microproject-us-congress/01-microproject-us-congress.ipynb#X25sZmlsZQ%3D%3D?line=17'>18</a> assert(len(df) - len(df_senate) - df_house.value_counts(df.columns.tolist()[12])[df.sort_values(df.columns.tolist()[6]).iloc[D][df.columns.tolist()[12]]] == republications_in_house)
#      <a href='vscode-notebook-cell:/Users/sabarishmogallapalli/Desktop/stat107/sm108/01-microproject-us-congress/01-microproject-us-congress.ipynb#X25sZmlsZQ%3D%3D?line=18'>19</a> print(f"{tada} Puzzle 2: All Tests Passed! {tada}")
#
# AssertionError:

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub and run the GitHub Actions Grader:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the instructions to commit and grade this MicroProject!
